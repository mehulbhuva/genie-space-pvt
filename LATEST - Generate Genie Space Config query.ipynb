# %%
from databricks.sdk import WorkspaceClient
 
w = WorkspaceClient()
 
space_id = "01f0eb354058139fbe1d4cd2285297da"  # BinTelligence Genie
 
# Fetch the full space config including serialized_space
resp = w.api_client.do(
    "GET",
    f"/api/2.0/genie/spaces/{space_id}",
    query={"include_serialized_space": "true"},
)
 
# Keep as raw JSON string — no need to parse and re-serialize
serialized_space = resp["serialized_space"]
 
print(f"Space: {resp['title']}")
print(f"JSON length: {len(serialized_space)} chars")
print(f"Preview: {serialized_space[:200]}...")

# %%
true, false, null = True, False, None  # allow pasting raw JSON literals as a Python dict

serialized_space = {
    "version": 2,
    "config": {
        "sample_questions": [
            {
                "id": "01f15e1b64271989845336bd642ff398",
                "question": [
                    "Build me a profile for a given batch number"
                ]
            }
        ]
    },
    "data_sources": {
        "tables": [
            {
                "identifier": "gso_prs_manufacturing_dev.bintelligence_app.corn_quality_results_view",
                "description": [
                    "Use this table to answer questions about quality outcomes. Quality results table that has Warm Germ scores, PST scores, and Warm Label scores. The Parent_batch_number should align to bulk_batch numbers from shelling_grid table. "
                ],
                "column_configs": [
                    {
                        "column_name": "analysis_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "completed_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "inspection_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_group_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "parent_batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "process_order_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "product_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "received_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_enterer",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_entry_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_max",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_min",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_name",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_status_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_text",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "result_value_amount",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sample_lab_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sample_status_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sampled_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "seed_parent_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "started_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "storage_location_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_lab_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_received_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_status_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "units_code",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_manufacturing_prod.bintelligence_app.field_dry_down",
                "description": [
                    "This table should be used to understand the moisture of a field. It will need to be connected to field_grid, which contains the base field information. This table contains details about how fields dry down over a growing season. The data in this table reflects various moisture samples at different points in time. Ultimately this table records moistures as certain periods in time. Important status of a field is whether the field is completed or not. Fields falling below 28% moisture and have not been completed should always be highlighted in analysis. "
                ],
                "column_configs": [
                    {
                        "column_name": "count_of_moisture_sample",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "covariance_field_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_field_id_ak",
                        "description": [
                            "ID that identifies the current field. Alternate key that enables joins to field_grid table. "
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_field_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "daily_dry_down_rate_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "defol_product_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_duration_hours_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_sensitivity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "drying_rate_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_date_pk",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "growing_plant",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_complete_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_field_moisture_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_field_moisture_sample",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_field_sample_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_max_field_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_min_field_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_group_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_field_moisture_percent_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_max_field_moisture_percent_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_min_field_moisture_percent_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sample_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sample_vs_predict_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "stdev_field_moisture_samples",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_manufacturing_prod.bintelligence_app.field_grid",
                "description": [
                    "This table is the record of all of the fields used for production. This table should join with field_dry_down for analysis related to field moisture and field status. Field_complete is an important indicator that signals if a field is harvested or not. Fields that have a moisture observation below 28% and do not have a status of complete should be highlighted in analysis. Current_field_id_ak is how this table joins to field_dry_down. Current_field_id_ak is how this table joins to hybrid_dex_current on the field_number column. batch_number in field_grid will also join to hyrbid_dex_current field_number column. This table joins to scale_ticket_view on batch_number. If scale_ticket_view received trucks (represented by a scale ticket) have receiving moistures that are wildly different that what is tracked in field_dry_down, this should be highlighted in analysis and you should learn what the expected moisture of a field should be based on receiving moisture compared to field_dry_down insights. \n"
                ],
                "column_configs": [
                    {
                        "column_name": "agronomist_name",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "batch_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "certification_required_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_day_predicted_field_moisture_percent_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_day_predicted_field_moisture_percent_max_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_day_predicted_field_moisture_percent_min_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_field_id_ak",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_field_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "days_from_most_recent_sample_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "defol_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "defol_rec",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_sensitivity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "estimated_80k_trucks_number_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "estimated_bins_default_number_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "estimated_gb_trucks_number_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "estimated_harvest_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "estimated_units_80k_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "estimated_units_gb_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "estimated_units_kg_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "female_area_acre",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_batch_seed_area",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_complete_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_latitude",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_longitude",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_output_batch_id_pk",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fifty_percent_shed_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fifty_percent_silk_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "gcr_plant",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "gross_interior_area_acre",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "growing_plant",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "growing_region",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "harvest_complete_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "is_split_batch",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "latest_moisture_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_yield_estimate_80k",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_yield_estimate_gb",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_yield_estimate_kg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "male_destroy_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_security_code",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "moisture_to_go_percent_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "most_recent_sample_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "pioneer_lot_number_suffix",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "planting_priority",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "process_order_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "purpose",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "row_ratio",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "seed_segment",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "truck_estimate_bushel_conversion",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current",
                "column_configs": [
                    {
                        "column_name": "GB_in_dryer_bin",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "actual_hours_into_drying",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "actual_shelled_volume_kg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "adjusted_downair",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "adjusted_downair_index",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "adjusted_predicted_end_time",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "adjusted_predicted_end_time_flag",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "adjusted_upair",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "adjusted_upair_index",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "batch_number_ak",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "bin_empty_overnight_flag",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "bin_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "comments_for_prediction_change",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "corner_bin_flag",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "crop_year",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "current_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_field_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dex_status",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "downair_index_derived",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "downtime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dried_shelled_received_kg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_bin_fill_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_bin_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_end_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_material",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_nside",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_side",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_start_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_status",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_type",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "drying_lot_number_ak",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "drying_rate",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "drying_time_downair_hours_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "drying_time_upair_hours_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "empty_after_receiving_hours",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "empty_day_fill_cutoff",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "field_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_available_hours_lost",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "fill_depth_feet",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_depth_mt",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_empty_end_time",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "fill_empty_end_time_hour",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "fill_end_date_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_end_time_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_number",
                        "description": [
                            "Indicates the fill number for the dryer bin. "
                        ],
                        "synonyms": [
                            "fill order"
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_start_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_start_date_hour",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "fill_start_hour",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_start_time",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "filling_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_ready_date_avg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_ready_date_max",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_ready_date_min",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "hours",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "hybridex_key_pk",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "item_type",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "last_refresh_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "latest_prediction_time",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "lbs_per_GB_at_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_security_code",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "moisture_difference",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "moisture_target",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "next_day_receiving_hours",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "next_fill_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "next_fill_hybridex_key",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "next_fill_number",
                        "description": [
                            "Fill number of the next filling cycle for a dryer bin."
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "next_fill_start_time",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "next_hybridex_key",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "number_of_field_trucks",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "odd_or_even",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "plant_code",
                        "description": [
                            "Code that identifies the plant or facility at which the material was dried"
                        ],
                        "synonyms": [
                            "Drying plant",
                            "receiving plant"
                        ],
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "predicted_drying_rate_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_harvest_moisture_avg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_harvest_moisture_max",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_harvest_moisture_min",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_hours_to_complete_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "predicted_total_drying_time_hours_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "prediction_type",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "previous_hybridex_key",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "propotional_field_estimate_kg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "qbe_TPT_kg",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "qbe_UPH_GBR",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "qbe_UPH_kg",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "restart_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelled_volume_GB",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "shelled_volume_kg",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "sheller_assigned_flag",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "shelling_end_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_start_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_time_hours",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "status",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "theoretical_TPT",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "theoretical_UPH_GBR",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "theoretical_UPH_kg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_to_midnight",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "time_to_next_fill",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_to_turn",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_to_turn_productive_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "timezone",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "unloading_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "upair_index_derived",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "volume_per_hour_GBR",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "volume_per_hr_kg",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "volume_per_hr_kg_at_shelled_moisture",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "waiting_to_shell",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "waiting_to_start",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view",
                "column_configs": [
                    {
                        "column_name": "audit_data_quality_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_created_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_processing_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_updated_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_comments",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "batch_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "beans_left_in_bin",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bin_discard_batch_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bin_inventory_abandonment_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bin_output_batch_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bin_unload_charge_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_output_batch_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bushels_left_in_bin",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "carrier_vendor_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "cleanout_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "cleanout_units",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "comments",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "created_as_load_ticket",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "created_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "creator",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "delivered_quantity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "delivery_note_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "delivery_note_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "delivery_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "discard_elevator_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "discard_sales_order_delivery",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "discard_sales_order_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dockage_fee",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_bin_fill_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_bin_fill_number_2",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_bin_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_bin_number_2",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "field_abandonment_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_output_batch_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "foreign_material_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "from_split_load",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "gross_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "grower_service_premium",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "hauling_distance",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "hauling_distance_uom",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "inspection_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "inspection_lot_sap_status",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "is_excluded_from_low_clean_out_quality_incentive",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "is_optional_contract",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "last_load",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "legacy_load_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "load_distribution_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "load_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "load_ticket_code",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "load_ticket_id_derived",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "male_seed",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_group",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "moisture_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "moisture_units",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "net_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "original_shipment_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "payment_units",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "plant_arrival_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_code",
                        "description": [
                            "Code that identifies the plant or facility in which the material was grown. "
                        ],
                        "synonyms": [
                            "Growing plant",
                            "originating location",
                            "growing location",
                            "sending plant",
                            "export plant"
                        ],
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "plant_departure_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "process_order_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "receiving_line",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "receiving_plant",
                        "synonyms": [
                            "Receiving plant",
                            "receiving location",
                            "import",
                            "important location"
                        ],
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "revised_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "revisor",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "sap_ticket_units",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "scale_in_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "scale_out_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "scale_ticket_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "scale_ticket_type",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "seed_quality_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "send_ticket_to_plant_system",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shipment",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "shipping_point_code",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "source_system_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "special_process_indicator",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "split_load_index",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "split_total_gross_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "split_total_tare_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "status_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "storage_location_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "system_end_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "system_start_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "tare_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "ticket_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "ticket_units",
                        "description": [
                            "Number of units recorded or processed on the ticket. This is considered a bushel. "
                        ],
                        "synonyms": [
                            "bushels",
                            "volume",
                            "received volume",
                            "green bushels"
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "ticket_units_uom",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "total_dockage_fee",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "truck_departure_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "truck_driver_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "truck_driver_name",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "truck_empty",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "truck_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "truck_plate_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "truck_status_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "truck_type_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "unload_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "unload_start_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "verified_by",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "warehouse_output_batch_abandonment_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "warehouse_output_batch_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "weight_unit",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_manufacturing_prod.bintelligence_wip.dias_fills",
                "description": [
                    "This table has the dryer information for sites on DIAS. This would be for CHA1, DYS1, RID1, and WOR1 for harvest year 2025. "
                ],
                "column_configs": [
                    {
                        "column_name": "actual_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "downair_complete",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "downair_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_bin_number",
                        "description": [
                            "Dryer Bin Number. Use the first digit of the dryer bin number to identify dryer number (e.g., 112 would be dryer 1, dryer bin 112)"
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "drying_complete",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "end_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_cleaning",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_downair",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_empty",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_filling",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_restart",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_shelling",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_upair",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_venting",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "et_time_waiting",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "facility",
                        "description": [
                            "This identifies plant_code"
                        ],
                        "synonyms": [
                            "plant code"
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_batch",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_number",
                        "description": [
                            "Chronological fill number to represent which number of fill the dryer bin is on. "
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "hybrid_dex_key",
                        "description": [
                            "hybrid_dex_key; use this to connect into hybrid_dex_current "
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "initial_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_cleaning",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_downair",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_empty",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_filling",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_restart",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_shelling",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_upair",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_venting",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "st_time_waiting",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "start_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "stopped_drying_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_cleaning_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_downair_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_empty_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_filling_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_restart_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_shelling_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_upair_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_venting_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "time_waiting_minutes",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "unique_tracking_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "upair_complete",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "upair_count",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_manufacturing_prod.bintelligence_wip.resourcelabor_fills",
                "column_configs": [
                    {
                        "column_name": "actual_end",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bin_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "downair_complete",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "downair_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "downair_drying_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "downair_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "downair_start_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "drying_complete",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "empty_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "empty_start_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "empty_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "facility",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "field_batch",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "fill_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "filling_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "filling_start_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "filling_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "hybrid_dex_key",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "lot_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "restart_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "restart_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "restart_hours",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "restart_start_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sheller_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sheller_start_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "upair_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "upair_drying_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "upair_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "upair_start_datetime",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_supply_chain_dev.batch_lineage.batch_lineage_with_sample_size_lineage",
                "description": [
                    "This table shows the relationship between a sampled and sized batch (finished batch), the bulk batch, the field batch, and base batch. Use this as a reference when you are given a set of batch numbers without any specifying what they are. \n",
                    "\n",
                    "Also use this as a reference for all batch lineage related items. Data throughout BinTelligence is user entered, so there can be errors in batch numbers. Treat this as the official system batch reference.  "
                ],
                "column_configs": [
                    {
                        "column_name": "base_batch_number",
                        "description": [
                            "CHARG - Base Batch numbers associated with material run through locations. This will probably be the batch number the user is providing you. "
                        ]
                    },
                    {
                        "column_name": "bulk_batch_number",
                        "description": [
                            "REFBATCH - Bulk Batch Number"
                        ],
                        "synonyms": [
                            "bulk batch",
                            "bulk"
                        ]
                    },
                    {
                        "column_name": "field_batch_number",
                        "description": [
                            "CHARG - Field Batch Number"
                        ],
                        "synonyms": [
                            "field batch",
                            "field output batch"
                        ]
                    },
                    {
                        "column_name": "sample_size_batch_number",
                        "description": [
                            "Sample size batch number. These are the batch numbers that are children of bulk batch numbers. "
                        ],
                        "synonyms": [
                            "sample size batch",
                            "sample batch",
                            "sized batch"
                        ]
                    }
                ]
            },
            {
                "identifier": "gso_prs_supply_chain_dev.batch_lineage.batch_lineage_with_sample_size_lineage_with_fact_result",
                "column_configs": [
                    {
                        "column_name": "Comment1",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment2",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment3",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment4",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment5",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment6",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment7",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment8",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "GermPercent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm1",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm2",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm3",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm4",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm5",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm6",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm7",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Norm8",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_batch_type",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_global_seed_size_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_harvest_timester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_inspection_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_material_group_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_material_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_material_suffix",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_old_material_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_pioneer_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_pioneer_lot_number_split",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_plant_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_plant_conditioned_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_plant_grown_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Sample_size_storage_location_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds1",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds2",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds3",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds4",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds5",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds6",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds7",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Seeds8",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TestAuthDate",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TreatmentR3",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn1",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn2",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn3",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn4",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn5",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn6",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn7",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "abn8",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_batch_conditioning_loss_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_batch_in_restricted_stock_use_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_batch_stabilization_loss_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_batch_type",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_blocked_stock_quantity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_global_seed_size_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_inspection_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_material_group_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_material_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_material_suffix",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_old_material_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_pioneer_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_pioneer_lot_number_split",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_plant_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_plant_conditioned_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_plant_grown_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_restricted_stock_quantity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_seeds_per_kg_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_storage_location_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_unrestricted_stock_quantity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_uom_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_base_uom_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_batch_conditioning_loss_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_batch_in_restricted_stock_use_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_batch_stabilization_loss_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_blocked_stock_quantity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_inspection_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_material",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_material_group_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_material_group_code_ipsloc",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_material_number_ipsloc",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_material_suffix",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_material_suffix_ipsloc",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_pioneer_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_pioneer_lot_number_split",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_plant_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_plant_conditioned_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_plant_grown_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_restricted_stock_quantity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_seeds_per_kg_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_storage_location_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_unrestricted_stock_quantity",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead1",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead2",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead3",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead4",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead5",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead6",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead7",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dead8",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_harvest_trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_material",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_material_group_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_material_suffix",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_old_material",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_pioneer_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_pioneer_lot_number_split",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_plant_grown_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "geid",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sample_origin",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sample_size_batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "siid",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_location_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_sample_ID",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "test_status_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "testnumber",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_prs_supply_chain_prod.global_inventory_management.batch_characteristics",
                "column_configs": [
                    {
                        "column_name": "acremax_major_component_batch_number_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "acremax_minor_component_batch_number_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "base_uom_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "basic_material_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_conditioning_loss_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_descr",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_in_restricted_stock_use_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_stabilization_loss_percent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_treatment_code_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "certification_type_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "certified_country_or_region_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "certified_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "certified_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "country_intended_use_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_freeze_event_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "generation_varietal_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "global_seed_size_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "gross_package_kg_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_season_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "harvest_year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "legal_crop_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "local_seed_size_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "market_quality_group_code_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_descr",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_group_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_type_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "mm_bags_per_pallet_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "mm_field_bin_source_code_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "mm_material_segment_code_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "mm_quality_status_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "mm_reference_batch_number_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "net_package_kg_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "old_material_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "origin_country_and_region_code_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "package_type_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "parent_bag_type_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "planned_certification_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_batch_delete_data_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_conditioned_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_dried_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_grown_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_treated_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "production_stage_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "quality_concern_code_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "quality_group_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sample_size_batch_number_list",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "seed_category_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "seeds_per_kg_count",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelf_life_expiration_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sterility_type_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "tag_germination_percent",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_rfd_manufacturing_prod.bintelligence.receivinggrid",
                "description": [
                    "Receivinggrid is the table that is generated based on the production locations capturing information about each truck that arrives. The load ticket ID in receivinggrid should be related to load ticket ID derived in scale_ticket_view. "
                ],
                "column_configs": [
                    {
                        "column_name": "audit_data_quality_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_created_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_processing_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_updated_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "batch_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bintell_field_complete_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bintell_receiving_grid_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bu_per_truck",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "comments",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_field_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "current_field_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_bin",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_fill_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "field_output_batch_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "gcr_plant",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "growing_plant",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "load_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "load_ticket_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "lot_no",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_security_code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "modified_on",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "operator",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "receiving_dump_line",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "receiving_line",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "receiving_line_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "receiving_line_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "receiving_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "scheduled_harvest_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "truck_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "unload_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "unload_end_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "unload_start_time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "unload_time",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_rfd_manufacturing_prod.bintelligence.shellergrid",
                "column_configs": [
                    {
                        "column_name": "audit_data_quality_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_created_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_processing_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "audit_refined_updated_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bintell_sheller_grid_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_batch",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "bulk_bin",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_bin_complete",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_fill_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "bulk_fill_order",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "comments",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "cumulative_bulk_weight",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_bin",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "dryer_bin_text",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "dryer_side",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "fill_depth_ft",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "fill_depth_mt",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "gcr_plant",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "hybrid_dex_key",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "material_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "material_security_code",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "modified_on",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "operator",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "pioneer_lot_number",
                        "enable_format_assistance": true,
                        "enable_entity_matching": true
                    },
                    {
                        "column_name": "process_order",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "scheduled_shelling_date",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelled_weight_kg",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sheller_assigned_flag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sheller_line_day_order",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sheller_run_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "sheller_run_number",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_complete",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_duration",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_end_datetime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_line_id",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_line_name",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "shelling_start_datetime",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_sandbox_dev.mike_larson_dev.corn_season_dates",
                "column_configs": [
                    {
                        "column_name": "FirstDayofDrying",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Harvest_Trimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Harvest_Year",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "LastDayofDrying",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Plant Code",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TotalDryingDays",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_sandbox_dev.mike_larson_dev.cornplan_26",
                "description": [
                    "This is the growing plan for corn and crop year 2026. MaterialName will be common connector across other tables in Genie space."
                ],
                "column_configs": [
                    {
                        "column_name": "AdjustedPollenPopulation",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "AdjustedSeedPopulation",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "AdjustmentComment",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "ApFreeFlag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "BudgetAreaCode",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "BudgetConversion",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Cancelled",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "CertificationRequired",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "CreatedDate",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Creator",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "DefolFlag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "EstimatedArea",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "EstimatedAreaUom",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "FemaleAreaPercent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "GSFMGrowingPlanId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "GrowingPlanId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "GrowingZoneId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "HarvestTrimester",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "HarvestYear",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "IsRegulated",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "IsSterile",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "IsolationRequired",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "IsolationTimeRequired",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "LocalExport",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "LockedFlag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaleAreaPercent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaleReferenceNumber",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaterialGroupCode",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaterialName",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaterialSecurityCode",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaterialStageCode",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaterialSuffix",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "OffSeasonFlag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "OnHold",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "ParentDeliveryDate",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PercentConditioningLoss",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PercentStabilizationLoss",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PhytosanitaryTestRequired",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PlantCode",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PlantGrowingArea",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PlantingPriority",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PollenParent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PollenParentPrismId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PreliminaryFlag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PrismId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "ProductId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Purpose",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "ReferenceNumber",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "RefreshDate",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "RegulatoryStatus",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "RevisedDate",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Revisor",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "S4MaterialId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "S4PollenParent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "S4SeedParent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SaveMaleFlag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SeedParent",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SeedParentPrismId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SeedsPerKilogram",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Separator",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SourceSystemGuid",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SourceSystemId",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Stewarded",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SyncedOn",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SystemEndTime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "SystemStartTime",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TargetEstimatedDryYield",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TargetEstimatedIrrigatedYield",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TargetEstimatedStdDryYield",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TargetEstimatedStdIrrigatedYield",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TargetEstimatedStdYieldUom",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TargetEstimatedYieldUom",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TargetYieldPaymentUnits",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "TransgenicFlag",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "UnitsRequested",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "UnitsRequestedUom",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_sandbox_dev.mike_larson_dev.hybridex_pnw",
                "description": [
                    "Only use for locations HES1 and CNN1. This file contains data about parent corn material (material group 019) drying data. It is similar to hybrid_dex_current, but specific to three plants that dry parent corn material. "
                ],
                "column_configs": [
                    {
                        "column_name": "# of Bins",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Bin",
                        "description": [
                            "dryer bin number"
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "BulkBatch",
                        "description": [
                            "careful using this field for an exact bulk batch reference. This field will contain multiple batches that came from a bulk batch. "
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Comment",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "CropYear",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Down Air Avg Intlet (°F)",
                        "description": [
                            "Use this column for temperature analysis of down air temps."
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Down Air Avg Outlet (°F)",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Down Air Index",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Down Air Time%",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Down Air Wetbulb (°F)",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Dryer",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "DryerType",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Drying Rate",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Female Inbred",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Fill Depth (ft)",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Fill#",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Hybrid",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Hybrid-Dex Key",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Max Shelling Moisture Reading",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Min Shelling Moisture Reading",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PST Germ",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "PioneerLotNo",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Pressure Down Air (INH2O)",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Pressure Up Air (INH2O)",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Quality Result",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Receiving Moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Shelling End Time",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Shelling Moisture",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Site",
                        "description": [
                            "plant location code"
                        ],
                        "synonyms": [
                            "plant_code"
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Started Drying",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Stopped Drying",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Total Drying Hours",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Up Air Avg Inlet (°F)",
                        "description": [
                            "Use this column for temperature analysis of up air temps."
                        ],
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Up Air Avg Outlet (°F)",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Up Air Index",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Up Air Time%",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Up Air Wetbulb (°F)",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Warm Germ",
                        "enable_format_assistance": true
                    }
                ]
            },
            {
                "identifier": "gso_sandbox_dev.mike_larson_dev.network_plants",
                "column_configs": [
                    {
                        "column_name": "Address 1",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "City",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Country",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Crop",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "First Built",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Latitude",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Longitude",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "MaterialGroup",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Network",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Owned",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Ownership Type",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Region",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Simple Site Name",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "Site Name",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "State/Region",
                        "enable_format_assistance": true
                    },
                    {
                        "column_name": "plant_code",
                        "enable_format_assistance": true
                    }
                ]
            }
        ]
    },
    "instructions": {
        "text_instructions": [
            {
                "id": "01f0eb35ceca10da82c1f88cb0a708ac",
                "content": [
                    "##Data Context\n",
                    "You are a seed corn grain drying advisor and your knowledge base contains corn seed production and harvest process data. You will answer questions to a variety of stakeholders on harvest and stabilization process. Be professional and informative in responses. Do not use overly aggressive words to describe opportunities or where locations do not meet standards--convey these findings as opportunities to strengthen and improve.\n",
                    "\n",
                    "At the end of all analysis, review the analysis to ensure all calculated insights are saying the same thing (e.g., if you mention drying rate conformance at the beginning, and then you mention it again later, review to ensure the calculated output is the same number). \n",
                    "\n",
                    "##Process Context\n",
                    "- Material arrives as \"green corn bushel\" (on the ear) and is dried using industrial double-pass reversible grain dryers or single-pass grain dryer to reach target moisture of 12.5%.\n",
                    "- Always pull shelling moistures from shellergrid - Do not use shelling_moisture from hybrid_dex_current for shelling moisture analysis. \n",
                    "- It costs $2 per KG to produce corn seed in North America\n",
                    "- Present quality loss estimates using the $2 per KG assumption - Do not use this assumption for capacity loss. \n",
                    "- Present capacity loss estimates in terms of KGs or total units (North America unit is called an 80K and on average weights 25KG) or total days of harvest. \n",
                    "- Present all opportunities as \"value levers\" or actions the sites can take to create value, and provide a high level estimate of what the non-financial value would be (e.g., 'if we can shorten wait times, we can take off X number of days to harvest')\n",
                    "- Do not use the word \"compliance\" use the word \"conformance.\" \n",
                    "- Use positive and motivating language to desbribe location and network opportunities.\n",
                    "\n",
                    "## Key Entities\n",
                    "- **Commercial Corn**: Identified by material group 010; when user asks about \"Corn\" analysis, you should confirm if they are asking about commercial corn (material group = 010) or parent corn (material group = 019)\n",
                    "- **Parent Corn**: Identified by material group 019. \n",
                    "- **Actual Drying Dates**: Identified by the dates inbetween 'FirstDayofDrying' and 'LastDayofDrying' in corn_season_dates table. \n",
                    "- When asked about a specific country, pass p_group_type = 'country'\n",
                    "- When asked about all US locations, use p_group_type = 'region', p_group_values = ARRAY('NA'), p_country_filter = ARRAY('USA')\n",
                    "- When asked about all North America, use p_group_type = 'region', p_group_values = ARRAY('NA'), p_country_filter = NULL\"\n",
                    "- When asked about Latin America or Brazil, use p_group_type = 'region', p_group_values = ARRAY('LA') and set trimester to 1 or 2 \n",
                    "- **Plant Locations**: Identified by `plant_code`. Brazil plants: \"FMA1\", \"ITU1\". All others are North America locations.\n",
                    "- **Dryer Bin Fills**: Each `hybridex_key_pk` (Harvest Year + Trimester + Location + Bin Number + Fill Number) represents a single dryer bin fill. Each dryer bin fill will have one or many truck loads which fill the dryer bin. \n",
                    "- **Truck Load**: Identified by `load_ticket_id_derived` (batch_number + load_number)\n",
                    "- **Material Hierarchy**: Pioneer_lot_number → multiple fields (current_field_id_ak) → field_output_batch_id_pk → batch_number\n",
                    "- **Units**: Unless otherwise explicitly specified with a unit of measure in a column name (e.g., KG), by a SQL query, or function, all context related to units should be referred to as Green Bushels\n",
                    "- **Variance and Quality Status**: Comments in 'Quality Status columns typically have notes that could impact product quality (E.g., \"BUVAR\" means Business Unit accepted a variance on the product when scores were slightly below threshold)\n",
                    "- **Quality Results**: when analyzing quality results, use bulk_batch number from shellergrid, and reference the parent_batch_number in corn_quality_results_view to get quality test result; always use plant_code from shellergrid to determine the location at which the corn was dried - Do not use Plant_code from corn_quality_results_view\n",
                    "-- **Components**: Any column named material_ID or material_number should be checked for values starting with 'IRC', and those should be labeled as \"minor component\" everything else would be considered a \"major component\"\n",
                    "- When analyzing dryer bin fills or any time-based production data, always join on the corn_season_dates table using Plant Code, Harvest_Year, and Harvest_Trimester. Only include records where timestamps fall between FirstDayofDrying and LastDayofDrying for the matching plant and season. Raw fill data contains test fills and non-real fills outside the actual season dates that must be excluded from all analyses. The corn_season_dates table is the authoritative source for when a plant's drying season begins and ends.\n",
                    "- **Growing Plant**: growing_plant column in receivinggrid or plant_code in scale_ticket_view is the source plant. \n",
                    "- **Receiving Plant**: The gcr_plant column in receivinggrid and receiving_plant in scale_ticket_view is the receiving plant.\n",
                    "- **Drying Rate**: Utilize the drying_rate_table function for all drying rate analysis; ignore all other functions, queries and columns that may contain drying rate information. \n",
                    "- **Field Status**: Indicated in field_grid on column field_complete_flag where '0' is incomplete and '1' is complete. \n",
                    "- **Harvest Ready Fields**: Fields that are incomplete harvest status and have an average moisture below 37%. The celing is 37%.   \n",
                    "- **Risky Fields**: Fields that are incomplete harvest status and have a moisture below 28% moisture. \n",
                    "\n",
                    "## Business Rules\n",
                    "- Small North America locations which should not be used as a benchmark comparison include CHA1, CHA9, RID1, RID9, DYS1, UTI1 \n",
                    "- Largest North America locations which should be core to broad network analyses include DON1, CON1, PLY1, YOR1, DUR1, TOL1, REI1, PRI1, STJ1\n",
                    "- Two different batch numbers cannot be in the same dryer bin\n",
                    "- Dryer bins should operate 24/7 from first fill to last fill of season\n",
                    "- Receiving moisture goal: above 32% (valid range: 10%-40%)\n",
                    "- Target dried moisture: 12.5%\n",
                    "- Ideal drying rate (North America): 3.5-4.5 hours per point of moisture removed\n",
                    "- Any drying rate (North America) outside of the 3.5 to 4.5 range is considered non-conforming; a higher drying rate does not indicate better performance\n",
                    "- Ideal drying rate (Brazil): 5.0 hours per point of moisture removed \n",
                    "- Locations should maximize same-material shelling runs to minimize changeovers\n",
                    "- Warm Germ score passing threshold is 95%, can be varianced down to 90%\n",
                    "- PST scores which are CC4SK-R3 threshold is 85%, can be varianced down to 75%\n",
                    "\n",
                    "## Key Metrics\n",
                    "- **Bin Occupied Duration**: Time between fill start and empty end (hours)\n",
                    "- **Total Drying Time**: Time dryers actively moving air (dryer_start to dryer_end)\n",
                    "- **Drying Rate**: Hours per point of moisture removed; use the drying rate reference query to calculate\n",
                    "- **Time to Turn Productive**: Time for bin to go from one fill to next (minimize this)\n",
                    "- **Dryer Turn**: Days to fill and empty every bin in a dryer\n",
                    "- **Drying Rates should be returned as a number with two decimal points. It is not a percentage. \n",
                    "- **Warm Germ Quality Scores**: Final Warm Germ score is identified in corn_quality_results_view using the CCWL-R3 or CCWT-R3 analysis_code \n",
                    "- **PST Quality Scores**: Final PST score is indentified in corn_quality_results_view using the CC4SK-R3 or CC4S2-R3 analysis_code\n",
                    "\n",
                    "## Data Filtering Defaults\n",
                    "- For season analysis: Only include `dex_status = 'complete'`\n",
                    "- Exclude `dex_status = 'Future fill'`\n",
                    "- For efficiency analysis: Exclude negative `time_to_next_fill` values\n",
                    "- `time_to_next_fill > 200` typically indicates end-of-season fills\n",
                    "- Ignore using waiting_to_start column in all analysis \n",
                    "\n",
                    "## Summary Analysis Expectations \n",
                    "- Any time you use a percentage in a calcuation or visual, ask yourself if it makes sense to allow a value to be over 100%. \n",
                    "- Provide comprehensive and detailed summaries when a user asks for summarizations\n",
                    "- Use a combination of visuals, high level summaries followed by supporting bullet points, and data tables\n",
                    "- Build data tables in a way that minimizes a user needing to horizontally scroll to see all columns\n",
                    "- Only include columns that are absolutely necessary to the comprehensive summary\n",
                    "- Use narrow page margins on any PDF generated downloads\n",
                    "- Include Page numbers on PDF generated documents\n",
                    "- Conclude all analyses with a summary and confirmation to reader giving them confidence that all calculated insights were reviewed for consistency within the given analysis output\n",
                    "\n",
                    "\n",
                    "### Lot-Suffix Resolution & Batch Lineage Tracing\n",
                    "## Lot-Suffix Resolution for Batch Tracing\n",
                    "\n",
                    "When a user provides a finished product batch number or a pioneer lot number with a `-0` suffix, operational drying/receiving/shelling data will NOT be found under that exact identifier. Apply this resolution pattern:\n",
                    "\n",
                    "### Pioneer Lot Suffix Convention\n",
                    "- **`-D` suffix**: Raw/drying stage — used in hybrid_dex_current, scale_ticket_view, receivinggrid, shellergrid\n",
                    "- **`-0` suffix**: Finished product — used in batch_characteristics (final), quality complaints\n",
                    "- **`-N` suffix**: Variant lots sent to alternate locations\n",
                    "\n",
                    "### Resolution Steps (Given a finished batch number):\n",
                    "1. Query `batch_lineage_with_sample_size_lineage` WHERE base_batch_number = given batch → get field_batch_number, bulk_batch_number, sample_size_batch_number\n",
                    "2. Query `batch_characteristics` WHERE batch_number = given batch → get pioneer_lot_number, plant_dried_code, plant_grown_code\n",
                    "3. Transform the lot suffix: replace `-0` with `-D` (or use LIKE on the base lot, e.g., 'T3CON13098%')\n",
                    "4. Query operational tables using the TRANSFORMED lot number\n",
                    "\n",
                    "### Which Column to Use in Each Table:\n",
                    "- **hybrid_dex_current**: Search by `pioneer_lot_number = '<lot>-D'` — DO NOT rely on batch_number_ak matching lineage field_batch_number (sibling field batches exist)\n",
                    "- **scale_ticket_view**: Use `batch_number` = lineage field_batch_number (direct match works) OR pioneer_lot_number\n",
                    "- **receivinggrid**: Use `batch_number` = lineage field_batch_number (direct match works) OR pioneer_lot_number\n",
                    "- **shellergrid**: Use `bulk_batch` = lineage bulk_batch_number (direct match works) OR pioneer_lot_number\n",
                    "- **corn_quality_results_view**: Use `parent_batch_number` = lineage bulk_batch_number\n",
                    "\n",
                    "### Why hybrid_dex_current Requires Lot-Based Lookup:\n",
                    "A pioneer lot has multiple sibling field batches (e.g., 6928804, 6928805, 6928807, 6931652). Lineage identifies ONE field batch as the ancestor, but hybrid_dex_current may track drying under a DIFFERENT sibling. All siblings share the same lot, material, plant, and season. Pioneer lot number is the ONLY reliable connector.\n",
                    "\n",
                    "### Material ID Changes Across Stages:\n",
                    "- Field: `{root}-1001` (e.g., 1013A303-31-1001)\n",
                    "- Bulk: `{root}-2019` (e.g., 1013A303-31-2019)\n",
                    "- Sample: `{root}-2105` (e.g., 1013A303-31-2105)\n",
                    "- Final: New branded number (e.g., P14830AML-NI01, old_material_number: 1013A303-43)\n",
                    "\n",
                    "To verify material identity across stages: match on `old_material_number` root or pioneer_lot_number base (highest confidence).\n",
                    "\n",
                    "### Material Profile Dossier Generation\n",
                    "## Material Profile Dossier\n",
                    "\n",
                    "When a user asks for a material profile, material summary, or \"what do we know about material X,\" generate a dossier-style overview using this pattern:\n",
                    "\n",
                    "### How to Identify Material Across Tables\n",
                    "- The user will provide a root material ID (e.g., `1013A303-39`). This maps to `old_material_number` in batch_characteristics.\n",
                    "- Query batch_characteristics WHERE old_material_number = given material AND harvest_year = requested year to get:\n",
                    "  - All pioneer_lot_numbers (use field-stage material suffix `-1002` to get unique lots)\n",
                    "  - Production footprint: plant_grown_code, plant_dried_code\n",
                    "  - Product description, trait stack (mm_material_segment_code_list)\n",
                    "\n",
                    "### How to Connect to Operational Tables\n",
                    "- Extract the lot BASE from pioneer_lot_number (e.g., T3DON13019 from T3DON13019-ND)\n",
                    "- Search operational tables using LIKE on the base: `pioneer_lot_number LIKE 'T3DON13019%'`\n",
                    "- This catches all lot suffix variants (-ND, -GND, -D, -NDX, etc.)\n",
                    "\n",
                    "### Dossier Sections (in order):\n",
                    "1. **Executive Summary**: Total volume (green bushels), locations count, headline signals\n",
                    "2. **Production Footprint**: Growing plant → Drying plant routing with lot counts\n",
                    "3. **Receiving Performance**: By location — truck loads, total GB, avg moisture, % above 32% target\n",
                    "4. **Drying Performance**: By location — fills, avg bin moisture, avg drying rate, conformance %, days active\n",
                    "5. **Quality Outcomes**: Final product status distribution, Warm Germ scores, PST scores by location with non-conformance counts\n",
                    "6. **Key Signals**: Priority-ranked findings with recommended investigation areas\n",
                    "\n",
                    "### Signal Classification:\n",
                    "- **Critical**: Drying conformance <30%, PST non-conformance >70%, WG non-conformance >50%\n",
                    "- **High**: Drying conformance 30-50%, PST 40-70%, WG 25-50%\n",
                    "- **Moderate**: Drying conformance 50-70%, PST 20-40%, WG 10-25%\n",
                    "- **Acceptable**: Drying conformance >70%, PST <20%, WG <10%\n",
                    "\n",
                    "### Key Rules:\n",
                    "- Lead with SIGNALS, not raw data — tell the reader what matters and where to look further\n",
                    "- Use comparative tables across locations — the value is side-by-side performance\n",
                    "- Never present a percentage over 100%\n",
                    "- Receiving moisture target: ≥32% (higher = better)\n",
                    "- Drying rate ideal (NA): 3.5-4.5 hrs/pt\n",
                    "- WG threshold: 95% (variance to 90%)\n",
                    "- PST threshold: 85% (variance to 75%)\n",
                    "- Drying rate = (dryer_end_time - dryer_start_time in hours) / (bin_moisture - shelling_moisture)\n",
                    "- Always use `old_material_number` from batch_characteristics as the root material key\n",
                    "- Quality data: join shellergrid.bulk_batch to corn_quality_results_view.parent_batch_number; use plant from shellergrid not quality view\n",
                    "- Include a Material Identity Cross-Reference table showing all stage variants of the material number"
                ]
            }
        ],
        "example_question_sqls": [
            {
                "id": "01f0eb49610a1a5ba766bab5bc80d0aa",
                "question": [
                    "What is the total bin restart count and how many total hours were associated with restarts?"
                ],
                "sql": [
                    "SELECT\n",
                    "  *,\n",
                    "  SUM(restart_count) OVER () AS total_restart_count\n",
                    "FROM\n",
                    "  gso_prs_manufacturing_prod.bintelligence_wip.resourcelabor_fills\n",
                    "WHERE\n",
                    "  restart_count IS NOT NULL\n",
                    "  AND harvest_year = :param"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ]
            },
            {
                "id": "01f100724cf514aa868e8547aff144c1",
                "question": [
                    "Evaluates drying rate performance against ideal range (3.5-4.5 hrs/point) for North America locations only."
                ],
                "sql": [
                    "SELECT \n",
                    "    plant_code,\n",
                    "    dryer_number,\n",
                    "    COUNT(*) AS total_fills,\n",
                    "    ROUND(AVG(drying_rate), 2) AS avg_drying_rate,\n",
                    "    ROUND(MIN(drying_rate), 2) AS min_drying_rate,\n",
                    "    ROUND(MAX(drying_rate), 2) AS max_drying_rate,\n",
                    "    SUM(CASE WHEN drying_rate BETWEEN 3.5 AND 4.5 THEN 1 ELSE 0 END) AS fills_in_ideal_range,\n",
                    "    ROUND(100.0 * SUM(CASE WHEN drying_rate BETWEEN 3.5 AND 4.5 THEN 1 ELSE 0 END) / COUNT(*), 1) AS pct_in_ideal_range\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\n",
                    "WHERE dex_status = 'complete'\n",
                    "    AND plant_code NOT IN ('FMA1', 'ITU1')\n",
                    "    AND drying_rate IS NOT NULL\n",
                    "    AND harvest_year = :param\n",
                    "GROUP BY plant_code, dryer_number\n",
                    "ORDER BY plant_code, dryer_number ASC"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING",
                        "default_value": {
                            "values": [
                                "2025"
                            ]
                        }
                    }
                ]
            },
            {
                "id": "01f101d89c551d7b90868f20869ac50e",
                "question": [
                    "Provides season-level summary statistics for completed fills by plant location. Use this for questions about plant performance, total production, or season overview."
                ],
                "sql": [
                    "SELECT \r\n",
                    "    hdc.plant_code,\r\n",
                    "    CASE \r\n",
                    "        WHEN hdc.plant_code IN ('FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'SRO1') \r\n",
                    "            THEN 'Brazil' \r\n",
                    "        ELSE 'North America' \r\n",
                    "    END AS region,\r\n",
                    "    COUNT(DISTINCT hdc.hybridex_key_pk) AS total_fills,\r\n",
                    "    COUNT(DISTINCT hdc.dryer_bin_number) AS bins_used,\r\n",
                    "    COUNT(DISTINCT hdc.dryer_number) AS dryers_used,\r\n",
                    "    SUM(hdc.shelled_volume_kg) AS total_shelled_kg,\r\n",
                    "    ROUND(AVG(hdc.drying_rate), 2) AS avg_drying_rate,\r\n",
                    "    csd.FirstDayofDrying AS season_start,\r\n",
                    "    csd.LastDayofDrying AS season_end\r\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current hdc\r\n",
                    "JOIN gso_sandbox_dev.mike_larson_dev.corn_season_dates csd\r\n",
                    "  ON hdc.plant_code = csd.`Plant Code`\r\n",
                    "  AND hdc.harvest_year = csd.Harvest_Year\r\n",
                    "WHERE hdc.dex_status = 'complete'\r\n",
                    "  AND hdc.harvest_year = :param\r\n",
                    "GROUP BY \r\n",
                    "    hdc.plant_code,\r\n",
                    "    csd.FirstDayofDrying,\r\n",
                    "    csd.LastDayofDrying\r\n",
                    "ORDER BY hdc.plant_code\r\n"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING",
                        "default_value": {
                            "values": [
                                "2025"
                            ]
                        }
                    }
                ]
            },
            {
                "id": "01f101d9334a1bb19156b3457029e528",
                "question": [
                    "Analyzes dryer bin efficiency metrics excluding invalid records. Use for questions about bin utilization, turn times, or efficiency"
                ],
                "sql": [
                    "SELECT \r\n",
                    "    plant_code,\r\n",
                    "    CASE WHEN plant_code IN ('FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'SRO1') THEN 'Brazil' ELSE 'North America' END AS region,\r\n",
                    "    dryer_number,\r\n",
                    "    dryer_bin_number,\r\n",
                    "    COUNT(*) AS total_fills,\r\n",
                    "    ROUND(AVG(time_to_next_fill), 2) AS avg_time_to_next_fill_hrs,\r\n",
                    "    ROUND(AVG(time_to_turn_productive_derived), 2) AS avg_time_to_turn_productive_hrs,\r\n",
                    "    ROUND(AVG(TIMESTAMPDIFF(HOUR, dryer_start_time, dryer_end_time)), 2) AS avg_drying_duration_hrs\r\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\r\n",
                    "WHERE dex_status = 'complete'\r\n",
                    "    AND time_to_next_fill >= 0\r\n",
                    "    AND time_to_next_fill <= 200\r\n",
                    "    AND harvest_year = :param\r\n",
                    "GROUP BY plant_code, dryer_number, dryer_bin_number\r\n",
                    "ORDER BY plant_code, dryer_number, dryer_bin_number\r\n"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ]
            },
            {
                "id": "01f101d9af381b1eac5e44b73621242e",
                "question": [
                    "Calculates dryer turn (days to fill and empty all bins in a dryer) by dryer and time period"
                ],
                "sql": [
                    "WITH fill_dates AS (\r\n",
                    "    SELECT \r\n",
                    "        plant_code,\r\n",
                    "        dryer_number,\r\n",
                    "        dryer_bin_number,\r\n",
                    "        fill_number,\r\n",
                    "        fill_start_date_hour,\r\n",
                    "        fill_empty_end_time_hour,\r\n",
                    "        DATE(fill_start_date_hour) AS fill_date\r\n",
                    "    FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\r\n",
                    "    WHERE dex_status = 'complete'\r\n",
                    "    AND harvest_year = :param\r\n",
                    "),\r\n",
                    "dryer_cycles AS (\r\n",
                    "    SELECT \r\n",
                    "        plant_code,\r\n",
                    "        dryer_number,\r\n",
                    "        fill_date,\r\n",
                    "        COUNT(DISTINCT dryer_bin_number) AS bins_filled,\r\n",
                    "        MIN(fill_start_date_hour) AS cycle_start,\r\n",
                    "        MAX(fill_empty_end_time_hour) AS cycle_end\r\n",
                    "    FROM fill_dates\r\n",
                    "    GROUP BY plant_code, dryer_number, fill_date\r\n",
                    ")\r\n",
                    "SELECT \r\n",
                    "    plant_code,\r\n",
                    "    CASE WHEN plant_code IN ('FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'SRO1') THEN 'Brazil' ELSE 'North America' END AS region,\r\n",
                    "    dryer_number,\r\n",
                    "    COUNT(DISTINCT fill_date) AS operating_days,\r\n",
                    "    SUM(bins_filled) AS total_bin_fills,\r\n",
                    "    ROUND(AVG(bins_filled), 1) AS avg_bins_per_day\r\n",
                    "FROM dryer_cycles\r\n",
                    "GROUP BY plant_code, dryer_number\r\n",
                    "ORDER BY plant_code, dryer_number\r\n"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING",
                        "default_value": {
                            "values": [
                                "2026"
                            ]
                        }
                    }
                ]
            },
            {
                "id": "01f101da7eb6173ab5ca08bac670e924",
                "question": [
                    "Returns detailed fill information for completed fills only. Base query for drill-down analysis"
                ],
                "sql": [
                    "SELECT \r\n",
                    "    hybridex_key_pk,\r\n",
                    "    plant_code,\r\n",
                    "    CASE WHEN plant_code IN ('FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'SRO1') THEN 'Brazil' ELSE 'North America' END AS region,\r\n",
                    "    dryer_number,\r\n",
                    "    dryer_bin_number,\r\n",
                    "    fill_number,\r\n",
                    "    dex_status,\r\n",
                    "    fill_start_date_hour,\r\n",
                    "    fill_empty_end_time_hour,\r\n",
                    "    TIMESTAMPDIFF(HOUR, fill_start_date_hour, fill_empty_end_time_hour) AS bin_occupied_hours,\r\n",
                    "    dryer_start_time,\r\n",
                    "    dryer_end_time,\r\n",
                    "    TIMESTAMPDIFF(HOUR, dryer_start_time, dryer_end_time) AS drying_hours,\r\n",
                    "    drying_rate,\r\n",
                    "    CASE \r\n",
                    "        WHEN plant_code IN ('FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'SRO1') THEN 'N/A - Brazil'\r\n",
                    "        WHEN drying_rate BETWEEN 3.5 AND 4.5 THEN 'Ideal'\r\n",
                    "        WHEN drying_rate < 3.5 THEN 'Too Fast'\r\n",
                    "        WHEN drying_rate > 4.5 THEN 'Too Slow'\r\n",
                    "        ELSE 'Unknown'\r\n",
                    "    END AS drying_rate_performance,\r\n",
                    "    shelled_volume_kg,\r\n",
                    "    time_to_next_fill,\r\n",
                    "    time_to_turn_productive_derived\r\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\r\n",
                    "WHERE dex_status = 'complete'\r\n",
                    "AND harvest_year = :param\r\n",
                    "ORDER BY plant_code, dryer_number, bin_number, fill_number\r\n"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ]
            },
            {
                "id": "01f1075ebc0a15f6b494b6889d7238dc",
                "question": [
                    "Bulk Bin Batch Shelling Moisture CV"
                ],
                "sql": [
                    "SELECT \r\n",
                    "  CONCAT(bulk_batch, '-', bulk_bin) AS bulk_bin_batch,\r\n",
                    "  (STDDEV(shelling_moisture) / AVG(shelling_moisture)) * 100 AS shelling_moisture_cv,\r\n",
                    "  AVG(shelling_moisture) AS avg_shelling_moisture,\r\n",
                    "  STDDEV(shelling_moisture) AS stddev_shelling_moisture,\r\n",
                    "  COUNT(*) AS sample_count\r\n",
                    "FROM gso_rfd_manufacturing_prod.bintelligence.shellergrid\r\n",
                    "WHERE shelling_moisture IS NOT NULL\r\n",
                    "AND harvest_year = :param\r\n",
                    "GROUP BY CONCAT(bulk_batch, '-', bulk_bin)"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ],
                "usage_guidance": [
                    "This should be used when users ask about bulk batch summaries. Coefficient of Variation on shelling moisture must always be included in bulk analysis. "
                ]
            },
            {
                "id": "01f1076012fd189b82cc20f5d20319a1",
                "question": [
                    "Average Receiving Moisture Batch"
                ],
                "sql": [
                    "SELECT \r\n",
                    "  batch_number,\r\n",
                    "  AVG(moisture_percent) AS avg_moisture_percent,\r\n",
                    "  COUNT(*) AS ticket_count,\r\n",
                    "  MIN(moisture_percent) AS min_moisture,\r\n",
                    "  MAX(moisture_percent) AS max_moisture\r\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view\r\n",
                    "WHERE moisture_percent IS NOT NULL\r\n",
                    "  AND batch_number IS NOT NULL\r\n",
                    "  AND harvest_year = :param\r\n",
                    "GROUP BY batch_number"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ]
            },
            {
                "id": "01f10760954f1ff9ae65eddace622a06",
                "question": [
                    "Bins_on_going"
                ],
                "sql": [
                    "SELECT \r\n",
                    "  plant_code AS location,\r\n",
                    "  dryer_number,\r\n",
                    "  harvest_year,\r\n",
                    "  COUNT(*) AS ongoing_fills_count\r\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\r\n",
                    "WHERE dex_status = 'ongoing'\r\n",
                    "  AND harvest_year = :param  -- Can be parameterized\r\n",
                    "GROUP BY plant_code, dryer_number, harvest_year\r\n",
                    "ORDER BY plant_code, dryer_number"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ],
                "usage_guidance": [
                    "This returns the total bins that are in an ongoing state."
                ]
            },
            {
                "id": "01f10761993618f6bec421cf7e722484",
                "question": [
                    "Bins_complete"
                ],
                "sql": [
                    "SELECT \r\n",
                    "  plant_code AS location,\r\n",
                    "  dryer_number,\r\n",
                    "  harvest_year,\r\n",
                    "  COUNT(*) AS ongoing_fills_count\r\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\r\n",
                    "WHERE dex_status = 'complete'\r\n",
                    "  AND harvest_year = :param  -- Can be parameterized\r\n",
                    "GROUP BY plant_code, dryer_number, harvest_year\r\n",
                    "ORDER BY plant_code, dryer_number  "
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ]
            },
            {
                "id": "01f107628364100baa303c0d58f80eea",
                "question": [
                    "Total_fills_location"
                ],
                "sql": [
                    "SELECT \r\n",
                    "  plant_code AS location,\r\n",
                    "  harvest_year,\r\n",
                    "  COUNT(*) AS total_ongoing_fills\r\n",
                    "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\r\n",
                    "WHERE dex_status = 'complete'\r\n",
                    "  AND harvest_year = :param\r\n",
                    "GROUP BY plant_code, harvest_year\r\n",
                    "ORDER BY plant_code"
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING"
                    }
                ]
            },
            {
                "id": "01f10c34b0831be99e5f0c8d94b35ab5",
                "question": [
                    "Harvest Ready vs Harvest Actual"
                ],
                "sql": [
                    "SELECT\r\n",
                    "  plant_code,\r\n",
                    "  harvest_year,\r\n",
                    "  AVG(DATEDIFF(fill_start_date, harvest_ready_date_avg)) AS avg_days_behind_harvest_ready,\r\n",
                    "  MIN(DATEDIFF(fill_start_date, harvest_ready_date_avg)) AS min_days_behind_harvest_ready,\r\n",
                    "  MAX(DATEDIFF(fill_start_date, harvest_ready_date_avg)) AS max_days_behind_harvest_ready,\r\n",
                    "  COUNT(*) AS record_count\r\n",
                    "FROM\r\n",
                    "  gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\r\n",
                    "GROUP BY\r\n",
                    "  plant_code,\r\n",
                    "  harvest_year\r\n",
                    "ORDER BY\r\n",
                    "  plant_code,\r\n",
                    "  harvest_year"
                ]
            },
            {
                "id": "01f11e3e4bc81e60aaaa8c3c2de0da14",
                "question": [
                    "Brazil Receiving Volumes"
                ],
                "sql": [
                    "SELECT\r\n",
                    "  scale_ticket_view.receiving_plant,\r\n",
                    "  SUM(scale_ticket_view.ticket_units) AS total_receiving_volume,\r\n",
                    "  COUNT(DISTINCT scale_ticket_view.scale_ticket_id) AS ticket_count,\r\n",
                    "  ROUND(AVG(scale_ticket_view.ticket_units), 2) AS avg_ticket_volume\r\n",
                    "FROM\r\n",
                    "  gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view\r\n",
                    "WHERE\r\n",
                    "  scale_ticket_view.receiving_plant IN (\r\n",
                    "    'FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'PIL2', 'BSB1', 'SRO1'\r\n",
                    "  )\r\n",
                    "  AND scale_ticket_view.harvest_year = :harvest_year\r\n",
                    "  AND scale_ticket_view.material_group = '010'\r\n",
                    "  AND scale_ticket_view.harvest_trimester = :harvest_trimester\r\n",
                    "  AND scale_ticket_view.ticket_units IS NOT NULL\r\n",
                    "GROUP BY\r\n",
                    "  scale_ticket_view.receiving_plant\r\n",
                    "ORDER BY\r\n",
                    "  total_receiving_volume DESC"
                ],
                "parameters": [
                    {
                        "name": "harvest_year",
                        "type_hint": "STRING"
                    },
                    {
                        "name": "harvest_trimester",
                        "type_hint": "STRING"
                    }
                ],
                "usage_guidance": [
                    "Used to answer total receiving volumes for Brazil"
                ]
            },
            {
                "id": "01f1593523701bc7a6117158d958b176",
                "question": [
                    "Drying Rate - Reference Calculation"
                ],
                "sql": [
                    "WITH base AS (\r\n",
                    "    SELECT\r\n",
                    "        d.hybridex_key_pk,\r\n",
                    "        d.pioneer_lot_number,\r\n",
                    "        d.plant_code,\r\n",
                    "        d.dryer_start_time,\r\n",
                    "        d.dryer_end_time,\r\n",
                    "        d.bin_moisture,\r\n",
                    "        s.shelling_moisture,\r\n",
                    "        (UNIX_TIMESTAMP(d.dryer_end_time) - UNIX_TIMESTAMP(d.dryer_start_time)) / 3600.0\r\n",
                    "            AS drying_time_hrs,\r\n",
                    "        (d.bin_moisture - s.shelling_moisture)\r\n",
                    "            AS moisture_pts_removed,\r\n",
                    "        gso_sandbox_dev.mike_larson_dev.drying_rate_calc(\r\n",
                    "            d.dryer_start_time,\r\n",
                    "            d.dryer_end_time,\r\n",
                    "            d.bin_moisture,\r\n",
                    "            s.shelling_moisture\r\n",
                    "        ) AS drying_rate_hrs_per_pt\r\n",
                    "    FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current d\r\n",
                    "    LEFT JOIN gso_rfd_manufacturing_prod.bintelligence.shellergrid s\r\n",
                    "        ON d.hybridex_key_pk = s.hybrid_dex_key\r\n",
                    "    WHERE d.dryer_start_time IS NOT NULL\r\n",
                    "      AND d.dryer_end_time   IS NOT NULL\r\n",
                    ")\r\n",
                    "SELECT *\r\n",
                    "FROM base\r\n",
                    "WHERE drying_rate_hrs_per_pt IS NOT NULL;"
                ],
                "usage_guidance": [
                    "use for all drying rate calculations"
                ]
            },
            {
                "id": "01f15e004a691177b77509c64683ce47",
                "question": [
                    "How does a field, bulk, and base batch number relate? "
                ],
                "sql": [
                    "WITH base_keys AS (\r\n",
                    "  SELECT DISTINCT\r\n",
                    "      field_batch_number,\r\n",
                    "      bulk_batch_number,\r\n",
                    "      base_batch_number,\r\n",
                    "      CAST(NULL AS STRING) AS sample_size_batch_number\r\n",
                    "  FROM gso_prs_supply_chain_dev.batch_lineage.batch_lineage_with_sample_size_lineage\r\n",
                    "\r\n",
                    "  UNION ALL\r\n",
                    "\r\n",
                    "  SELECT DISTINCT\r\n",
                    "      field_batch_number,\r\n",
                    "      bulk_batch_number,\r\n",
                    "      base_batch_number,\r\n",
                    "      sample_size_batch_number\r\n",
                    "  FROM gso_prs_supply_chain_dev.batch_lineage.batch_lineage_with_sample_size_lineage\r\n",
                    "  WHERE sample_size_batch_number IS NOT NULL\r\n",
                    "),\r\n",
                    "enriched AS (\r\n",
                    "  SELECT\r\n",
                    "      bl.field_batch_number,\r\n",
                    "      bl.bulk_batch_number,\r\n",
                    "      bl.base_batch_number,\r\n",
                    "      bl.sample_size_batch_number,\r\n",
                    "\r\n",
                    "      bc_field.material_number as field_material_number,\r\n",
                    "\r\n",
                    "      bc_bulk.harvest_year            AS bulk_harvest_year,\r\n",
                    "      bc_bulk.material_number         AS bulk_material_number,\r\n",
                    "      bc_bulk.old_material_number     AS bulk_old_material,\r\n",
                    "      bc_bulk.material_group_code     AS bulk_material_group_code,\r\n",
                    "      bc_bulk.local_seed_size_code    AS bulk_local_seed_size_code,\r\n",
                    "      split(bc_bulk.pioneer_lot_number, '-')[0] AS bulk_pioneer_lot_number,\r\n",
                    "      bc_bulk.plant_grown_code        AS bulk_plant_grown_code,\r\n",
                    "      bc_bulk.plant_conditioned_code  AS bulk_plant_conditioned_code,\r\n",
                    "      ipslocbulk.storage_location_code    AS bulk_storage_location_code,\r\n",
                    "      -- zgb_bulk.grid_status_descr      AS bulk_grid_status_descr,\r\n",
                    "\r\n",
                    "\r\n",
                    "\r\n",
                    "      CASE\r\n",
                    "          WHEN zgo_base.batch_type_code = 'F'  THEN 'Finished Batch'\r\n",
                    "          WHEN zgo_base.batch_type_code = 'SS' THEN 'Sample Size'\r\n",
                    "          WHEN zgo_base.batch_type_code = 'C'  THEN 'Conditioned'\r\n",
                    "          ELSE NULL\r\n",
                    "      END                             AS base_batch_type,\r\n",
                    "      bc_base.harvest_year            AS base_harvest_year,\r\n",
                    "      bc_base.material_number         AS base_material_number,\r\n",
                    "      bc_base.old_material_number     AS base_old_material_number,\r\n",
                    "      bc_base.material_group_code     AS base_material_group_code,\r\n",
                    "      bc_base.local_seed_size_code    AS base_global_seed_size_code,\r\n",
                    "      split(bc_base.pioneer_lot_number, '-')[0]  AS base_pioneer_lot_number,\r\n",
                    "      bc_base.plant_grown_code        AS base_plant_grown_code,\r\n",
                    "      bc_base.plant_conditioned_code  AS base_plant_conditioned_code,\r\n",
                    "      ipslocbase.storage_location_code    AS base_storage_location_code,\r\n",
                    "      --zgb_base.grid_status_descr      AS base_grid_status_descr,\r\n",
                    "\r\n",
                    "      -- NULL AS actual_shipped_quantity,\r\n",
                    "      -- NULL AS unrestricted_stock_quantity,\r\n",
                    "      -- NULL AS restricted_stock_quantity,\r\n",
                    "\r\n",
                    "      -- is.actual_shipped_quantity,\r\n",
                    "      -- is.unrestricted_stock_quantity,\r\n",
                    "      -- is.restricted_stock_quantity,\r\n",
                    "\r\n",
                    "      ipslocbase.plant_code                                   AS base_plant_code,\r\n",
                    "      ipslocbase.storage_location_code                        AS base_storage_location_code_ipsloc,\r\n",
                    "      ipslocbase.material_group_code                          AS base_material_group_code_ipsloc,\r\n",
                    "      ipslocbase.material_number                              AS base_material_number_ipsloc,\r\n",
                    "      ipslocbase.base_uom_code                                AS base_base_uom_code,\r\n",
                    "      ipslocbase.seeds_per_kg_count                           AS base_seeds_per_kg_count,\r\n",
                    "      ipslocbase.batch_in_restricted_stock_use_flag           AS base_batch_in_restricted_stock_use_flag,\r\n",
                    "      ipslocbase.batch_stabilization_loss_percent             AS base_batch_stabilization_loss_percent,\r\n",
                    "      ipslocbase.batch_conditioning_loss_percent              AS base_batch_conditioning_loss_percent,\r\n",
                    "      ipslocbase.unrestricted_stock_quantity                  AS base_unrestricted_stock_quantity,\r\n",
                    "      ipslocbase.restricted_stock_quantity                    AS base_restricted_stock_quantity,\r\n",
                    "      ipslocbase.quality_inspection_stock_quantity            AS base_quality_inspection_stock_quantity,\r\n",
                    "      ipslocbase.blocked_stock_quantity                       AS base_blocked_stock_quantity,\r\n",
                    "      ipslocbase.planned_sto_quantity                         AS base_planned_sto_quantity,\r\n",
                    "      ipslocbase.intransit_sto_quantity                       AS base_intransit_sto_quantity,\r\n",
                    "      ipslocbase.actual_shipped_quantity                      AS base_actual_shipped_quantity,\r\n",
                    "      ipslocbase.estimated_units_for_process_orders_quantity  AS base_estimated_units_for_process_orders_quantity,\r\n",
                    "      ipslocbase.estimated_reservation_quantity               AS base_estimated_reservation_quantity,\r\n",
                    "      ipslocbase.estimated_reservation_discard_quantity       AS base_estimated_reservation_discard_quantity,\r\n",
                    "\r\n",
                    "\r\n",
                    "      CASE\r\n",
                    "          WHEN zgo_sample_size.batch_type_code = 'F'  THEN 'Finished Batch'\r\n",
                    "          WHEN zgo_sample_size.batch_type_code = 'SS' THEN 'Sample Size'\r\n",
                    "          WHEN zgo_sample_size.batch_type_code = 'C'  THEN 'Conditioned'\r\n",
                    "          ELSE NULL\r\n",
                    "      END                             AS Sample_size_batch_type,\r\n",
                    "      bc_sample_size.harvest_year            AS Sample_size_harvest_year,\r\n",
                    "      bc_sample_size.material_number         AS Sample_size_material_number,\r\n",
                    "      bc_sample_size.old_material_number     AS Sample_size_old_material_number,\r\n",
                    "      bc_sample_size.material_group_code     AS Sample_size_material_group_code,\r\n",
                    "      bc_sample_size.local_seed_size_code    AS Sample_size_global_seed_size_code,\r\n",
                    "      split(bc_sample_size.pioneer_lot_number, '-')[0]  AS Sample_size_pioneer_lot_number,\r\n",
                    "      bc_sample_size.plant_grown_code        AS Sample_size_plant_grown_code,\r\n",
                    "      bc_sample_size.plant_conditioned_code  AS Sample_size_plant_conditioned_code,\r\n",
                    "      ipslocsample.storage_location_code     AS sample_size_storage_location_code,\r\n",
                    "      -- zgb_sample_size.grid_status_descr     AS Sample_size_grid_status_descr,\r\n",
                    "\r\n",
                    "      t.AuthorizedDatetime            AS TestAuthDate,\r\n",
                    "      t.TestLocationCode              AS test_location_code,\r\n",
                    "      t.TestNumber                    AS testnumber, \r\n",
                    "\r\n",
                    "      r.ResultName                    AS result_name,\r\n",
                    "      r.ResultValueAmount             AS result_value_amount,\r\n",
                    "      r.AnalysisCode                  AS analysis_code,\r\n",
                    "      r.AnalysisType                  AS analysis_type\r\n",
                    "\r\n",
                    "  FROM base_keys bl\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_supply_chain_prod.global_inventory_management.batch_characteristics bc_field\r\n",
                    "    ON bl.field_batch_number = bc_field.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_supply_chain_prod.global_inventory_management.batch_characteristics bc_bulk\r\n",
                    "    ON bl.bulk_batch_number = bc_bulk.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_supply_chain_prod.global_inventory_management.batch_characteristics bc_base\r\n",
                    "    ON bl.base_batch_number = bc_base.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_supply_chain_prod.global_inventory_management.batch_characteristics bc_sample_size\r\n",
                    "    ON bl.sample_size_batch_number = bc_sample_size.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_supply_chain_prod.global_inventory_management.inventory_plant_sloc_batch ipslocbulk\r\n",
                    "    ON bl.base_batch_number = ipslocbulk.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_supply_chain_prod.global_inventory_management.inventory_plant_sloc_batch ipslocbase\r\n",
                    "    ON bl.base_batch_number = ipslocbase.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_supply_chain_prod.global_inventory_management.inventory_plant_sloc_batch ipslocsample\r\n",
                    "    ON bl.base_batch_number = ipslocsample.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_rfd_supply_chain_prod.sap_hana.zcs_grid_output_conditioning_system_batch_output zgo_base\r\n",
                    "    ON bl.base_batch_number = zgo_base.batch_number\r\n",
                    "\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_rfd_supply_chain_prod.sap_hana.zcs_grid_output_conditioning_system_batch_output zgo_sample_size\r\n",
                    "    ON bl.sample_size_batch_number = zgo_sample_size.batch_number\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_quality_prod.seed_quality_testing.fact_test t\r\n",
                    "    ON t.R3Batch = COALESCE(bl.sample_size_batch_number, bl.base_batch_number)  --- JOIN to batch number if no sample size batch.  \r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_quality_prod.seed_quality_testing.fact_result r\r\n",
                    "    ON t.TestNumber = r.TestNumber\r\n",
                    "\r\n",
                    "  LEFT JOIN gso_prs_quality_prod.seed_quality_testing.fact_sample s\r\n",
                    "    ON t.SampleId = s.SampleId\r\n",
                    "\r\n",
                    "  WHERE r.ResultName IN ('WL GERM', '4SKGERM', 'W GERM')\r\n",
                    "    AND t.AuthorizedDatetime IS NOT NULL\r\n",
                    "    AND r.ResultValueAmount <> 0\r\n",
                    "    and t.TestStatusCode = 'A'  --> Authorized.\r\n",
                    "    AND s.origin IN ('01','05','09','89') -->'04' used for repackaging ISL's, '05' used for new crop testing, '09' is for summer retesting  and '89' is for retesting\r\n",
                    "--    AND bl.bulk_batch_number IN ('7066475')\r\n",
                    "\r\n",
                    ")\r\n",
                    "SELECT DISTINCT \r\n",
                    "  -- Keys\r\n",
                    "  field_batch_number,\r\n",
                    "  bulk_batch_number,\r\n",
                    "  base_batch_number,\r\n",
                    "  sample_size_batch_number,\r\n",
                    "\r\n",
                    "  -- Bulk batch attributes\r\n",
                    "  bulk_harvest_year,\r\n",
                    "  bulk_material_number,\r\n",
                    "  bulk_old_material,\r\n",
                    "  bulk_material_group_code,\r\n",
                    "  bulk_local_seed_size_code,\r\n",
                    "  bulk_pioneer_lot_number,\r\n",
                    "  bulk_plant_grown_code,\r\n",
                    "  bulk_plant_conditioned_code,\r\n",
                    "  bulk_storage_location_code,\r\n",
                    "  --bulk_grid_status_descr,\r\n",
                    "\r\n",
                    "  -- Base batch attributes\r\n",
                    "  base_batch_type,\r\n",
                    "  base_harvest_year,\r\n",
                    "  base_material_number,\r\n",
                    "  base_old_material_number,\r\n",
                    "  base_material_group_code,\r\n",
                    "  base_global_seed_size_code,\r\n",
                    "  base_pioneer_lot_number,\r\n",
                    "  base_plant_grown_code,\r\n",
                    "  base_plant_conditioned_code,\r\n",
                    "  base_storage_location_code,\r\n",
                    "  --base_grid_status_descr,\r\n",
                    "\r\n",
                    "  -- Inventory\r\n",
                    "  -- actual_shipped_quantity,\r\n",
                    "  -- unrestricted_stock_quantity,\r\n",
                    "  -- restricted_stock_quantity,\r\n",
                    "  base_plant_code,\r\n",
                    "  base_storage_location_code_ipsloc,\r\n",
                    "  base_material_group_code_ipsloc,\r\n",
                    "  base_material_number_ipsloc,\r\n",
                    "  base_base_uom_code,\r\n",
                    "  base_seeds_per_kg_count,\r\n",
                    "  base_batch_in_restricted_stock_use_flag,\r\n",
                    "  base_batch_stabilization_loss_percent,\r\n",
                    "  base_batch_conditioning_loss_percent,\r\n",
                    "  base_unrestricted_stock_quantity,\r\n",
                    "  base_restricted_stock_quantity,\r\n",
                    "  base_quality_inspection_stock_quantity,\r\n",
                    "  base_blocked_stock_quantity,\r\n",
                    "  base_planned_sto_quantity,\r\n",
                    "  base_intransit_sto_quantity,\r\n",
                    "  base_actual_shipped_quantity,\r\n",
                    "  base_estimated_units_for_process_orders_quantity,\r\n",
                    "  base_estimated_reservation_quantity,\r\n",
                    "  base_estimated_reservation_discard_quantity,\r\n",
                    "\r\n",
                    "  -- Sample Size batch attributes\r\n",
                    "  Sample_size_batch_type,\r\n",
                    "  Sample_size_harvest_year,\r\n",
                    "  Sample_size_material_number,\r\n",
                    "  Sample_size_old_material_number,\r\n",
                    "  Sample_size_material_group_code,\r\n",
                    "  Sample_size_global_seed_size_code,\r\n",
                    "  Sample_size_pioneer_lot_number,\r\n",
                    "  Sample_size_plant_grown_code,\r\n",
                    "  Sample_size_plant_conditioned_code,\r\n",
                    "  Sample_size_storage_location_code,\r\n",
                    "  --Sample_size_grid_status_descr,\r\n",
                    "\r\n",
                    "  -- Testing\r\n",
                    "  TestAuthDate,\r\n",
                    "  test_location_code,\r\n",
                    "  testnumber,\r\n",
                    "\r\n",
                    "  -- Result fields\r\n",
                    "  result_name,\r\n",
                    "  result_value_amount,\r\n",
                    "  analysis_code,\r\n",
                    "  analysis_type\r\n",
                    "FROM enriched\r\n",
                    "WHERE field_batch_number = :param\r\n",
                    "ORDER BY field_batch_number, bulk_batch_number, bulk_material_number, base_batch_number, base_material_number, sample_size_batch_number, Sample_size_material_number;\r\n",
                    " "
                ],
                "parameters": [
                    {
                        "name": "param",
                        "type_hint": "STRING",
                        "default_value": {
                            "values": [
                                "field_batch_number"
                            ]
                        }
                    }
                ]
            },
            {
                "id": "01f1aef5b1171267ab0957008abf79e5",
                "question": [
                    "Ongoing North America Bins 2026"
                ],
                "sql": [
                    "SELECT\r\n",
                    "  `plant_code`,\r\n",
                    "  COUNT(DISTINCT `hybridex_key_pk`) AS ongoing_bins_count\r\n",
                    "FROM\r\n",
                    "  `gso_prs_manufacturing_prod`.`bintelligence_app`.`hybrid_dex_current`\r\n",
                    "WHERE\r\n",
                    "  `dex_status` = 'ongoing'\r\n",
                    "  AND `harvest_year` = 2026\r\n",
                    "  AND `plant_code` IN (\r\n",
                    "    'ALG1',\r\n",
                    "    'CHA1',\r\n",
                    "    'CHA9',\r\n",
                    "    'CON1',\r\n",
                    "    'DON1',\r\n",
                    "    'DUR1',\r\n",
                    "    'DYS1',\r\n",
                    "    'HED1',\r\n",
                    "    'PLY1',\r\n",
                    "    'PRI1',\r\n",
                    "    'REI1',\r\n",
                    "    'RID1',\r\n",
                    "    'RID9',\r\n",
                    "    'RUS1',\r\n",
                    "    'STJ1',\r\n",
                    "    'TIP1',\r\n",
                    "    'TOL1',\r\n",
                    "    'UTI1',\r\n",
                    "    'WOO1',\r\n",
                    "    'WOR1',\r\n",
                    "    'YOR1',\r\n",
                    "    'YOR4'\r\n",
                    "  )\r\n",
                    "GROUP BY\r\n",
                    "  `plant_code`\r\n",
                    "ORDER BY\r\n",
                    "  ongoing_bins_count DESC,\r\n",
                    "  `plant_code`"
                ]
            }
        ],
        "sql_functions": [
            {
                "id": "01f10db298e91a52b2078eccb4f87c96",
                "identifier": "gso_sandbox_dev.mike_larson_dev.material_profile_summary"
            },
            {
                "id": "01f10db5307e17888540b7c005570374",
                "identifier": "gso_sandbox_dev.mike_larson_dev.material_fill_status"
            },
            {
                "id": "01f10dc6389611d881d3adfe5acf750c",
                "identifier": "gso_sandbox_dev.mike_larson_dev.pioneer_lot_number"
            },
            {
                "id": "01f110cdcd401dec85c67e89049ec0c5",
                "identifier": "gso_sandbox_dev.mike_larson_dev.network_dryer_turn"
            },
            {
                "id": "01f110cf17d61614903b10a4ed0d677d",
                "identifier": "gso_sandbox_dev.mike_larson_dev.plant_dryer_turn"
            },
            {
                "id": "01f110cf2026151885c6c2d047b8e3f7",
                "identifier": "gso_sandbox_dev.mike_larson_dev.fill_drying_metrics"
            },
            {
                "id": "01f110cf243a1d55b820027abfdde154",
                "identifier": "gso_sandbox_dev.mike_larson_dev.material_receiving_moisture"
            },
            {
                "id": "01f111fa273c17188b006fd313e924cb",
                "identifier": "gso_sandbox_dev.mike_larson_dev.get_network_dryer_utilization"
            },
            {
                "id": "01f111fdf0cf1050b41052869e8702b1",
                "identifier": "gso_sandbox_dev.mike_larson_dev.get_plant_dryer_utilization"
            },
            {
                "id": "01f1278137731008bf5f444a810a01ba",
                "identifier": "gso_sandbox_dev.mike_larson_dev.get_cross_location_capacity_impact"
            },
            {
                "id": "01f12781462612eaa0e513c7c9239477",
                "identifier": "gso_sandbox_dev.mike_larson_dev.get_cross_location_receiving_summary"
            },
            {
                "id": "01f15934e8ba1430975d877782447199",
                "identifier": "gso_sandbox_dev.mike_larson_dev.drying_rate_table"
            }
        ],
        "join_specs": [
            {
                "id": "01f0eb3635ef1314a4e724f8e08a06ca",
                "left": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current",
                    "alias": "hybrid_dex_current"
                },
                "right": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view",
                    "alias": "scale_ticket_view"
                },
                "sql": [
                    "`hybrid_dex_current`.`batch_number_ak` = `scale_ticket_view`.`batch_number`",
                    "--rt=FROM_RELATIONSHIP_TYPE_MANY_TO_MANY--"
                ]
            },
            {
                "id": "01f0f64930f313508b9ffc48f13bc886",
                "left": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view",
                    "alias": "scale_ticket_view"
                },
                "right": {
                    "identifier": "gso_rfd_manufacturing_prod.bintelligence.receivinggrid",
                    "alias": "receivinggrid"
                },
                "sql": [
                    "`scale_ticket_view`.`load_ticket_id_derived` = `receivinggrid`.`load_ticket_id`",
                    "--rt=FROM_RELATIONSHIP_TYPE_ONE_TO_ONE--"
                ],
                "instruction": [
                    "Load_ticket_id in Scale_ticket_view represent an individual truck load. Each truck is received and load_ticket_id is captured in receiving grid"
                ]
            },
            {
                "id": "01f0fbc5384e1480b77c830aadd92944",
                "left": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current",
                    "alias": "hybrid_dex_current"
                },
                "right": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view",
                    "alias": "scale_ticket_view_2"
                },
                "sql": [
                    "`hybrid_dex_current`.`plant_code` = `scale_ticket_view_2`.`receiving_plant`",
                    "--rt=FROM_RELATIONSHIP_TYPE_MANY_TO_MANY--"
                ]
            },
            {
                "id": "01f12d2a094c16daa9f95cd5a0187166",
                "left": {
                    "identifier": "gso_rfd_manufacturing_prod.bintelligence.shellergrid",
                    "alias": "shellergrid"
                },
                "right": {
                    "identifier": "gso_prs_manufacturing_dev.bintelligence_app.corn_quality_results_view",
                    "alias": "corn_quality_results_view"
                },
                "sql": [
                    "`shellergrid`.`bulk_batch` = `corn_quality_results_view`.`parent_batch_number`",
                    "--rt=FROM_RELATIONSHIP_TYPE_ONE_TO_MANY--"
                ],
                "instruction": [
                    "Sheller Grid has the bulk batch output of the drying process, and corn_quality_results_view will show all the test results that came from this particular batch. "
                ]
            },
            {
                "id": "01f131fb029c1541a79e1462931e2a0c",
                "left": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current",
                    "alias": "hybrid_dex_current"
                },
                "right": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_wip.resourcelabor_fills",
                    "alias": "resourcelabor_fills"
                },
                "sql": [
                    "`hybrid_dex_current`.`drying_lot_number_ak` = `resourcelabor_fills`.`lot_number`",
                    "--rt=FROM_RELATIONSHIP_TYPE_ONE_TO_ONE--"
                ]
            },
            {
                "id": "01f131fc571c1085b31e7049a4211d04",
                "left": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current",
                    "alias": "hybrid_dex_current"
                },
                "right": {
                    "identifier": "gso_rfd_manufacturing_prod.bintelligence.receivinggrid",
                    "alias": "receivinggrid"
                },
                "sql": [
                    "`hybrid_dex_current`.`batch_number_ak` = `receivinggrid`.`batch_number`",
                    "--rt=FROM_RELATIONSHIP_TYPE_MANY_TO_MANY--"
                ]
            },
            {
                "id": "01f1af0d4a5c1298aa8ab4be2af4d9a0",
                "left": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.field_grid",
                    "alias": "field_grid"
                },
                "right": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.field_dry_down",
                    "alias": "field_dry_down"
                },
                "sql": [
                    "`field_grid`.`current_field_id_ak` = `field_dry_down`.`current_field_id_ak`",
                    "--rt=FROM_RELATIONSHIP_TYPE_ONE_TO_MANY--"
                ],
                "instruction": [
                    "field_grid contains all the production fields profile information and the status, whether it is harvested or if harvest is not yet complete. It joins to field_dry_down on current_field_id_ak which contains the moisture details of how the field is drying down based on the most recent moisture sample. Fields that fall below 28% which have not yet been completed should be highlighted when asked about field status and quality risk. "
                ]
            },
            {
                "id": "01f1af0f5c7b115a803d9306723f9f4c",
                "left": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.field_grid",
                    "alias": "field_grid"
                },
                "right": {
                    "identifier": "gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view",
                    "alias": "scale_ticket_view"
                },
                "sql": [
                    "`field_grid`.`batch_number` = `scale_ticket_view`.`batch_number`",
                    "--rt=FROM_RELATIONSHIP_TYPE_ONE_TO_MANY--"
                ],
                "instruction": [
                    "Scale_ticket_view shows all the truck loads that are received against a field and a batch_number. This batch_number join should align a single field to multiple scale_ticket_view records which are the trucks received from a planned batch. Scale_ticket_view truck loads will have a receiving moisture which is an important metric to the quality of our process. You should learn what is happening with the receiving moistures of each batch_number. If the receiving moistures are different that the sample observations in field_dry_down, this should be highlighted in analysis and summaries. "
                ]
            }
        ],
        "sql_snippets": {
            "filters": [
                {
                    "id": "01f0eb3b73be17ca96f7a0e3a9c6e659",
                    "sql": [
                        "`hybrid_dex_current`.`plant_code` IN ('ALG1',\r\n",
                        "      'CHA1','CHA9',\r\n",
                        "      'CON1',\r\n",
                        "      'DON1',\r\n",
                        "      'DUR1',\r\n",
                        "      'DYS1',\r\n",
                        "      'HED1',\r\n",
                        "      'PLY1',\r\n",
                        "      'PRI1',\r\n",
                        "      'REI1',\r\n",
                        "      'RID1','RID9',\r\n",
                        "      'RUS1',\r\n",
                        "      'STJ1',\r\n",
                        "      'TIP1',\r\n",
                        "      'TOL1',\r\n",
                        "      'UTI1',\r\n",
                        "      'WOO1',\r\n",
                        "      'WOR1',\r\n",
                        "      'YOR1',\r\n",
                        "      'YOR4')"
                    ],
                    "display_name": "every location in North America",
                    "instruction": [
                        "WHEN_TO_USE: When user asks for all North American locations, but other sites must not be included; SCOPE_TABLES: hybrid_dex_current; RISK_IF_MISUSED: Do not apply this filter unless user scope matches North America without those exceptions."
                    ]
                },
                {
                    "id": "01f11e3f429112cfbca08038b1aa9128",
                    "sql": [
                        "`hybrid_dex_current`.`dex_status` = 'complete'"
                    ],
                    "display_name": "completed shelling run",
                    "instruction": [
                        "WHEN_TO_USE: When user wants to count or analyze shelling runs after the operation is finished; SCOPE_TABLES: hybrid_dex_current; RISK_IF_MISUSED: Do not apply this filter if the scope includes in-progress or planned fills."
                    ]
                },
                {
                    "id": "01f11e3f4292197aae049ebf4441e494",
                    "sql": [
                        "`hybrid_dex_current`.`dryer_bin_number` IS NOT NULL"
                    ],
                    "display_name": "shelling runs with assigned dryer bin",
                    "instruction": [
                        "WHEN_TO_USE: Use when analysis pertains to material changeovers or inefficiency per dryer bin; SCOPE_TABLES: hybrid_dex_current; RISK_IF_MISUSED: Omitting this can lead to inaccurate aggregation and missed context."
                    ]
                },
                {
                    "id": "01f15e108a691061b34876ea12404e1f",
                    "sql": [
                        "hybrid_dex_current.fill_start_date_hour BETWEEN corn_season_dates.FirstDayofDrying AND corn_season_dates.LastDayofDrying"
                    ],
                    "display_name": "within official corn drying season",
                    "instruction": [
                        "WHEN_TO_USE: Use when analysis should only include dryer bin fills that occurred within the official start and end of the drying season for a plant's location, harvest year, and trimester; SCOPE_TABLES: hybrid_dex_current joined to corn_season_dates; TIMEFRAME_HINT: Applies only to event start times between FirstDayofDrying and LastDayofDrying. RISK_IF_MISUSED: Omitting this can cause inclusion of off-season, test, or non-production events, especially in year-over-year or location-based comparisons."
                    ]
                },
                {
                    "id": "01f15e10a1881c7d9142095a437bcfa7",
                    "sql": [
                        "scale_ticket_view.moisture_percent BETWEEN 10 AND 40"
                    ],
                    "display_name": "moisture_percent between 10 and 40",
                    "instruction": [
                        "WHEN_TO_USE: When analyzing tickets or receiving volumes for North American facilities where valid moisture readings are required; SCOPE_TABLES: scale_ticket_view; RISK_IF_MISUSED: Should NOT be used unless moisture-percent validity/quality is specifically requested, as it may bias summary statistics."
                    ]
                },
                {
                    "id": "01f16e4a044b14978f9be5c7532378c0",
                    "sql": [
                        "`hybrid_dex_current`.`plant_code` IN ('ITU1','ITU2','FMA1','BSB1')"
                    ],
                    "display_name": "every location in Brazil",
                    "instruction": [
                        "WHEN_TO_USE: When user asks for all Brazil plant locations, but other sites must not be included; SCOPE_TABLES: hybrid_dex_current; RISK_IF_MISUSED: Do not apply this filter unless user scope matches North America without those exceptions."
                    ]
                }
            ],
            "expressions": [
                {
                    "id": "01f1074d73f8163c8116e74daf110936",
                    "sql": [
                        "CASE WHEN scale_ticket_view.moisture_percent >= 32 THEN 'Target (≥32%)' WHEN scale_ticket_view.moisture_percent >= 25 THEN 'Acceptable (25-31.9%)' WHEN scale_ticket_view.moisture_percent >= 10 THEN 'Low (<25%)' ELSE 'Invalid Reading' END"
                    ],
                    "display_name": "Receiving Moisture Groups",
                    "instruction": [
                        "Categorizes incoming corn moisture levels (goal is above 32%)"
                    ],
                    "synonyms": [
                        "distribution of receiving moisture",
                        "receiving moisture quality"
                    ]
                }
            ],
            "measures": [
                {
                    "id": "01f10071765110c9bd0ddb38d2954075",
                    "sql": [
                        "TIMESTAMPDIFF(HOUR, hybrid_dex_current.fill_start_date_hour, hybrid_dex_current.fill_empty_end_time_hour)"
                    ],
                    "display_name": "Bin Occupied Duration (Hours)",
                    "instruction": [
                        "This measure should show the length of time and individual dryer bin was occupied between when it started filling and when it was finally emptied for a given fill. This should only be used to assess the duration of a dryer bin fill. "
                    ],
                    "synonyms": [
                        "time of fill",
                        "how long was it in use",
                        "fill duration",
                        "in use",
                        "total fill time"
                    ]
                },
                {
                    "id": "01f1075a5da911a29d488145fe1a22cf",
                    "sql": [
                        "SUM(CASE WHEN scale_ticket_view.moisture_percent >= 28.0 THEN scale_ticket_view.ticket_units ELSE 0 END)"
                    ],
                    "display_name": "Receiving Moisture Above 28%",
                    "instruction": [
                        "This should show the total volume of units that was harvested above a quality risk threshold. This metric is used in dashboards in conjunction with receiving moisture below 28% to create a view showing percent of material above or below 28%. "
                    ],
                    "synonyms": [
                        "how much was received above 28%"
                    ]
                },
                {
                    "id": "01f1075aa3d318b5ad395895e2285dac",
                    "sql": [
                        "SUM(CASE WHEN scale_ticket_view.moisture_percent < 28.0 THEN scale_ticket_view.ticket_units ELSE 0 END)"
                    ],
                    "display_name": "Receiving Moisture Below 28%",
                    "instruction": [
                        "This should show the total volume of units that was harvested below a quality risk threshold. This metric is used in dashboards in conjunction with receiving moisture above 28% to create a view showing percent of material above or below 28%. "
                    ],
                    "synonyms": [
                        "how much material was received below 28%"
                    ]
                },
                {
                    "id": "01f1075ff7cb140283611a063976bd47",
                    "sql": [
                        "AVG(scale_ticket_view.moisture_percent)"
                    ],
                    "display_name": "Average Receiving Moisture"
                },
                {
                    "id": "01f15e0ed75f1516b3cbd5bd42dd04e9",
                    "alias": "avg_days_behind_harvest_ready_date",
                    "sql": [
                        "ROUND(AVG(DATEDIFF(`hybrid_dex_current`.`fill_start_date`, `hybrid_dex_current`.`harvest_ready_date_avg`)), 2)"
                    ],
                    "display_name": "average days between harvest ready date and actual fill start date",
                    "instruction": [
                        "WHEN_TO_USE: When user requests the average interval from harvest ready to fill start, for a location or group; SCOPE_TABLES: hybrid_dex_current; TIMEFRAME_HINT: For calculations involving harvest_year or similar timeframes; RISK_IF_MISUSED: Do not assume this metric applies to all fills—ensure both dates are present."
                    ]
                },
                {
                    "id": "01f15e0ed7601d0c82b6d81c0468bbb4",
                    "alias": "min_days_behind_harvest_ready_date",
                    "sql": [
                        "MIN(DATEDIFF(`hybrid_dex_current`.`fill_start_date`, `hybrid_dex_current`.`harvest_ready_date_avg`))"
                    ],
                    "display_name": "minimum days between harvest ready date and actual fill start date",
                    "instruction": [
                        "WHEN_TO_USE: When analyzing shortest delay between harvest ready and fill start for a location/year; SCOPE_TABLES: hybrid_dex_current; TIMEFRAME_HINT: Group by plant_code and harvest_year as needed."
                    ]
                },
                {
                    "id": "01f15e0ed762133c83a8426306522209",
                    "alias": "max_days_behind_harvest_ready_date",
                    "sql": [
                        "MAX(DATEDIFF(`hybrid_dex_current`.`fill_start_date`, `hybrid_dex_current`.`harvest_ready_date_avg`))"
                    ],
                    "display_name": "maximum days between harvest ready date and actual fill start date",
                    "instruction": [
                        "WHEN_TO_USE: For reporting longest delay from harvest ready to fill start by location/year; SCOPE_TABLES: hybrid_dex_current; TIMEFRAME_HINT: Include harvest_year in analysis if requested."
                    ]
                },
                {
                    "id": "01f15e0fa3cc1019aacc88687e8c5fbe",
                    "alias": "total_restart_hours",
                    "sql": [
                        "ROUND(`bintelligence_wip`.`resourcelabor_fills`.`restart_hours`, 2)"
                    ],
                    "display_name": "total restart hours",
                    "instruction": [
                        "WHEN_TO_USE: Use when a user needs restart hours aggregated by group, especially for reporting or presentation, and expects numbers rounded to two decimals; SCOPE_TABLES: bintelligence_wip.resourcelabor_fills; RISK_IF_MISUSED: Do not use if the requirement is to show unrounded raw values."
                    ]
                },
                {
                    "id": "01f15e10a18a11d09a164962c4e37d07",
                    "alias": "pct_above_32_moisture",
                    "sql": [
                        "ROUND(SUM(CASE WHEN scale_ticket_view.moisture_percent >= 32.0 THEN scale_ticket_view.ticket_units ELSE 0 END) / SUM(scale_ticket_view.ticket_units) * 100, 2)"
                    ],
                    "display_name": "percentage of receiving volume above 32% moisture",
                    "instruction": [
                        "WHEN_TO_USE: When user wants to know the fraction (percent) of receiving volume above the 32% moisture threshold per location for a given harvest year; SCOPE_TABLES: scale_ticket_view; RISK_IF_MISUSED: Do not use if user requests count of tickets or average moisture, as this metric is volume-weighted and sensitive to the definition of 'above 32%'."
                    ]
                }
            ]
        }
    },
    "benchmarks": {
        "questions": [
            {
                "id": "01f16e4a34ec1638a39a13ee7effb5c5",
                "question": [
                    "What trends exist for low warm germ scores for material group 010 in North America during the 2025 harvest year, including product and production location insights?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  cqr.`material_number`,\n",
                            "  cqr.`plant_code`,\n",
                            "  np.`Simple Site Name` AS location_name,\n",
                            "  np.`Region`,\n",
                            "  COUNT(DISTINCT cqr.`inspection_lot_number`) AS total_tests,\n",
                            "  AVG(cqr.`result_value_amount`) AS avg_warm_germ_score,\n",
                            "  MIN(cqr.`result_value_amount`) AS min_warm_germ_score,\n",
                            "  MAX(cqr.`result_value_amount`) AS max_warm_germ_score,\n",
                            "  SUM(\n",
                            "    CASE\n",
                            "      WHEN cqr.`result_value_amount` < 95 THEN 1\n",
                            "      ELSE 0\n",
                            "    END\n",
                            "  ) AS tests_below_95,\n",
                            "  SUM(\n",
                            "    CASE\n",
                            "      WHEN cqr.`result_value_amount` < 90 THEN 1\n",
                            "      ELSE 0\n",
                            "    END\n",
                            "  ) AS tests_below_90,\n",
                            "  ROUND(\n",
                            "    100.0\n",
                            "      * SUM(\n",
                            "        CASE\n",
                            "          WHEN cqr.`result_value_amount` < 95 THEN 1\n",
                            "          ELSE 0\n",
                            "        END\n",
                            "      )\n",
                            "      / COUNT(*),\n",
                            "    1\n",
                            "  ) AS pct_below_95\n",
                            "FROM\n",
                            "  `gso_prs_manufacturing_dev`.`bintelligence_app`.`corn_quality_results_view` cqr\n",
                            "    LEFT JOIN `gso_sandbox_dev`.`mike_larson_dev`.`network_plants` np\n",
                            "      ON cqr.`plant_code` = np.`plant_code`\n",
                            "WHERE\n",
                            "  cqr.`analysis_code` IN ('CCWL-R3', 'CCWT-R3')\n",
                            "  AND cqr.`material_group_code` = '010'\n",
                            "  AND np.`Region` = 'North America'\n",
                            "  AND YEAR(cqr.`completed_datetime`) = 2025\n",
                            "  AND cqr.`result_value_amount` IS NOT NULL\n",
                            "GROUP BY\n",
                            "  cqr.`material_number`,\n",
                            "  cqr.`plant_code`,\n",
                            "  np.`Simple Site Name`,\n",
                            "  np.`Region`\n",
                            "HAVING\n",
                            "  COUNT(DISTINCT cqr.`inspection_lot_number`) >= 1\n",
                            "ORDER BY\n",
                            "  avg_warm_germ_score ASC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e43991b66996db4e051dbab1e",
                "question": [
                    "What are the PST quality scores by location for harvest year 2025, and which locations have batches below the 85% threshold?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  sg.gcr_plant AS plant_code,\n",
                            "  COUNT(DISTINCT qr.parent_batch_number) AS total_batches_tested,\n",
                            "  ROUND(AVG(qr.result_value_amount), 2) AS avg_pst_score,\n",
                            "  ROUND(MIN(qr.result_value_amount), 2) AS min_pst_score,\n",
                            "  ROUND(MAX(qr.result_value_amount), 2) AS max_pst_score,\n",
                            "  SUM(\n",
                            "    CASE\n",
                            "      WHEN qr.result_value_amount < 85 THEN 1\n",
                            "      ELSE 0\n",
                            "    END\n",
                            "  ) AS batches_below_85,\n",
                            "  SUM(\n",
                            "    CASE\n",
                            "      WHEN qr.result_value_amount >= 85 THEN 1\n",
                            "      ELSE 0\n",
                            "    END\n",
                            "  ) AS batches_at_or_above_85,\n",
                            "  ROUND(\n",
                            "    100.0\n",
                            "      * SUM(\n",
                            "        CASE\n",
                            "          WHEN qr.result_value_amount < 85 THEN 1\n",
                            "          ELSE 0\n",
                            "        END\n",
                            "      )\n",
                            "      / COUNT(*),\n",
                            "    1\n",
                            "  ) AS pct_below_85\n",
                            "FROM\n",
                            "  `gso_rfd_manufacturing_prod`.`bintelligence`.`shellergrid` sg\n",
                            "    JOIN `gso_prs_manufacturing_dev`.`bintelligence_app`.`corn_quality_results_view` qr\n",
                            "      ON sg.bulk_batch = qr.parent_batch_number\n",
                            "WHERE\n",
                            "  qr.analysis_code IN ('CC4SK-R3', 'CC4S2-R3')\n",
                            "  AND qr.result_value_amount IS NOT NULL\n",
                            "  AND YEAR(sg.scheduled_shelling_date) = 2025\n",
                            "GROUP BY\n",
                            "  sg.gcr_plant\n",
                            "ORDER BY\n",
                            "  avg_pst_score ASC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e438419228bfde3c4fda8568b",
                "question": [
                    "What is the average days between harvest ready date and actual fill start date by location for harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  plant_code,\n",
                            "  harvest_year,\n",
                            "  ROUND(AVG(DATEDIFF(fill_start_date, harvest_ready_date_avg)), 2) AS avg_days_behind_harvest_ready,\n",
                            "  MIN(DATEDIFF(fill_start_date, harvest_ready_date_avg)) AS min_days_behind,\n",
                            "  MAX(DATEDIFF(fill_start_date, harvest_ready_date_avg)) AS max_days_behind\n",
                            "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current\n",
                            "WHERE harvest_year = 2025\n",
                            "  AND dex_status = 'complete'\n",
                            "  AND harvest_ready_date_avg IS NOT NULL\n",
                            "GROUP BY plant_code, harvest_year\n",
                            "ORDER BY avg_days_behind_harvest_ready DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e430b15fa9269f27c7eae3d0d",
                "question": [
                    "How does the relationship between field batch, bulk batch, and base batch work for a given pioneer lot number?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  bl.`field_batch_number`,\n",
                            "  bl.`bulk_batch_number`,\n",
                            "  bl.`base_batch_number`,\n",
                            "  bl.`sample_size_batch_number`,\n",
                            "  SPLIT(bc_bulk.`pioneer_lot_number`, '-')[0] AS `pioneer_lot_number`,\n",
                            "  bc_field.`material_number` AS `field_material`,\n",
                            "  bc_bulk.`material_number` AS `bulk_material`,\n",
                            "  bc_base.`material_number` AS `base_material`,\n",
                            "  bc_sample.`material_number` AS `sample_size_material`,\n",
                            "  bc_bulk.`plant_grown_code` AS `plant_grown`,\n",
                            "  bc_bulk.`harvest_year`\n",
                            "FROM\n",
                            "  `gso_prs_supply_chain_dev`.`batch_lineage`.`batch_lineage_with_sample_size_lineage` bl\n",
                            "    LEFT JOIN `gso_prs_supply_chain_prod`.`global_inventory_management`.`batch_characteristics` bc_field\n",
                            "      ON bl.`field_batch_number` = bc_field.`batch_number`\n",
                            "    LEFT JOIN `gso_prs_supply_chain_prod`.`global_inventory_management`.`batch_characteristics` bc_bulk\n",
                            "      ON bl.`bulk_batch_number` = bc_bulk.`batch_number`\n",
                            "    LEFT JOIN `gso_prs_supply_chain_prod`.`global_inventory_management`.`batch_characteristics` bc_base\n",
                            "      ON bl.`base_batch_number` = bc_base.`batch_number`\n",
                            "    LEFT JOIN `gso_prs_supply_chain_prod`.`global_inventory_management`.`batch_characteristics` bc_sample\n",
                            "      ON bl.`sample_size_batch_number` = bc_sample.`batch_number`\n",
                            "WHERE\n",
                            "  bc_bulk.`pioneer_lot_number` IS NOT NULL\n",
                            "  AND bl.`base_batch_number` IS NOT NULL\n",
                            "LIMIT 5"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e42c8144fb8c47bb6b2290f55",
                "question": [
                    "What is the receiving volume for all US locations for harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  SUM(`scale_ticket_view`.`ticket_units`) AS total_us_receiving_volume,\n",
                            "  COUNT(DISTINCT `scale_ticket_view`.`receiving_plant`) AS plant_count,\n",
                            "  COUNT(DISTINCT `scale_ticket_view`.`scale_ticket_id`) AS total_tickets\n",
                            "FROM\n",
                            "  `gso_prs_manufacturing_prod`.`bintelligence_app`.`scale_ticket_view`\n",
                            "    JOIN `gso_sandbox_dev`.`mike_larson_dev`.`network_plants`\n",
                            "      ON `scale_ticket_view`.`receiving_plant` = `network_plants`.`plant_code`\n",
                            "WHERE\n",
                            "  `scale_ticket_view`.`harvest_year` = 2025\n",
                            "  AND `network_plants`.`Country` = 'USA'\n",
                            "  AND `scale_ticket_view`.`ticket_units` IS NOT NULL"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e42b2114c9c61409e580df6fc",
                "question": [
                    "Compare average shelling moisture by dryer and location for North America in harvest year 2025. Which dryers have the highest variability (CV%)?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  sg.gcr_plant AS plant_code,\n",
                            "  sg.dryer_number,\n",
                            "  COUNT(*) AS sample_count,\n",
                            "  ROUND(AVG(sg.shelling_moisture), 2) AS avg_shelling_moisture,\n",
                            "  ROUND(STDDEV(sg.shelling_moisture), 2) AS stddev_shelling_moisture,\n",
                            "  ROUND((STDDEV(sg.shelling_moisture) / AVG(sg.shelling_moisture)) * 100, 2) AS cv_pct\n",
                            "FROM gso_rfd_manufacturing_prod.bintelligence.shellergrid sg\n",
                            "WHERE sg.harvest_year = 2025\n",
                            "  AND sg.gcr_plant NOT IN ('FMA1', 'ITU1')\n",
                            "  AND sg.shelling_moisture IS NOT NULL\n",
                            "GROUP BY sg.gcr_plant, sg.dryer_number\n",
                            "ORDER BY cv_pct DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e428617f9aa1603c7870be7f1",
                "question": [
                    "What is the total restart count and total restart hours by location for harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  `facility` AS plant_code,\n",
                            "  SUM(`restart_count`) AS total_restart_count,\n",
                            "  SUM(`restart_hours`) AS total_restart_hours,\n",
                            "  COUNT(DISTINCT `hybrid_dex_key`) AS total_fills_with_restarts\n",
                            "FROM\n",
                            "  `gso_prs_manufacturing_prod`.`bintelligence_wip`.`resourcelabor_fills`\n",
                            "WHERE\n",
                            "  `harvest_year` = 2025\n",
                            "  AND `restart_count` IS NOT NULL\n",
                            "  AND `restart_hours` IS NOT NULL\n",
                            "GROUP BY\n",
                            "  `facility`\n",
                            "ORDER BY\n",
                            "  total_restart_hours DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e427219d9b9f82b6eb63654a6",
                "question": [
                    "What are the Warm Germ scores by location for harvest year 2025, and what percentage of batches failed the 95% threshold?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  sg.gcr_plant AS plant_code,\n",
                            "  COUNT(DISTINCT cqr.parent_batch_number) AS total_batches_tested,\n",
                            "  SUM(CASE WHEN cqr.result_value < 95 THEN 1 ELSE 0 END) AS batches_below_threshold,\n",
                            "  ROUND(SUM(CASE WHEN cqr.result_value < 95 THEN 1 ELSE 0 END) * 100.0 / COUNT(*), 2) AS pct_non_conforming,\n",
                            "  ROUND(AVG(cqr.result_value), 2) AS avg_warm_germ_score\n",
                            "FROM gso_rfd_manufacturing_prod.bintelligence.shellergrid sg\n",
                            "JOIN gso_prs_manufacturing_dev.bintelligence_app.corn_quality_results_view cqr\n",
                            "  ON sg.bulk_batch = cqr.parent_batch_number\n",
                            "WHERE cqr.analysis_code IN ('CCWL-R3', 'CCWT-R3')\n",
                            "  AND sg.harvest_year = 2025\n",
                            "GROUP BY sg.gcr_plant\n",
                            "ORDER BY pct_non_conforming DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e425c19318549c1532fd23334",
                "question": [
                    "What is the average time to next fill by dryer for the largest North America locations (DON1, CON1, PLY1, YOR1, DUR1, TOL1, REI1, PRI1, STJ1) in harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  `plant_code`,\n",
                            "  `dryer_number`,\n",
                            "  COUNT(*) AS total_fills,\n",
                            "  ROUND(AVG(`time_to_next_fill`), 2) AS avg_time_to_next_fill_hrs,\n",
                            "  ROUND(MIN(`time_to_next_fill`), 2) AS min_time_to_next_fill_hrs,\n",
                            "  ROUND(MAX(`time_to_next_fill`), 2) AS max_time_to_next_fill_hrs\n",
                            "FROM\n",
                            "  `gso_prs_manufacturing_prod`.`bintelligence_app`.`hybrid_dex_current`\n",
                            "WHERE\n",
                            "  `dex_status` = 'complete'\n",
                            "  AND `plant_code` IN ('DON1', 'CON1', 'PLY1', 'YOR1', 'DUR1', 'TOL1', 'REI1', 'PRI1', 'STJ1')\n",
                            "  AND `harvest_year` = 2025\n",
                            "  AND `time_to_next_fill` >= 0\n",
                            "  AND `time_to_next_fill` <= 200\n",
                            "  AND `time_to_next_fill` IS NOT NULL\n",
                            "GROUP BY\n",
                            "  `plant_code`,\n",
                            "  `dryer_number`\n",
                            "ORDER BY\n",
                            "  `plant_code`,\n",
                            "  `dryer_number`"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e42451af9a990aefba58623e4",
                "question": [
                    "What is the average bin occupied duration in hours by location for completed fills in harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  hdc.plant_code,\n",
                            "  COUNT(*) AS total_fills,\n",
                            "  ROUND(AVG(TIMESTAMPDIFF(HOUR, hdc.fill_start_date_hour, hdc.fill_empty_end_time_hour)), 2) AS avg_bin_occupied_hours\n",
                            "FROM gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current hdc\n",
                            "JOIN gso_sandbox_dev.mike_larson_dev.corn_season_dates csd\n",
                            "  ON hdc.plant_code = csd.plant_code\n",
                            "  AND hdc.harvest_year = csd.harvest_year\n",
                            "  AND hdc.harvest_trimester = csd.harvest_trimester\n",
                            "WHERE hdc.dex_status = 'complete'\n",
                            "  AND hdc.harvest_year = 2025\n",
                            "  AND hdc.fill_start_date_hour BETWEEN csd.FirstDayofDrying AND csd.LastDayofDrying\n",
                            "GROUP BY hdc.plant_code\n",
                            "ORDER BY avg_bin_occupied_hours"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e4231147d8a0a1d573d1ca1cd",
                "question": [
                    "What percentage of receiving volume came in above 32% moisture for each North America location in harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  stv.receiving_plant,\n",
                            "  COUNT(*) AS total_tickets,\n",
                            "  SUM(CASE WHEN stv.moisture_percent >= 32.0 THEN stv.ticket_units ELSE 0 END) AS units_above_32,\n",
                            "  SUM(stv.ticket_units) AS total_units,\n",
                            "  ROUND(SUM(CASE WHEN stv.moisture_percent >= 32.0 THEN stv.ticket_units ELSE 0 END) / SUM(stv.ticket_units) * 100, 2) AS pct_above_32\n",
                            "FROM gso_prs_manufacturing_prod.bintelligence_app.scale_ticket_view stv\n",
                            "WHERE stv.harvest_year = 2025\n",
                            "  AND stv.moisture_percent BETWEEN 10 AND 40\n",
                            "  AND stv.receiving_plant NOT IN ('FMA1', 'ITU1')\n",
                            "GROUP BY stv.receiving_plant\n",
                            "ORDER BY pct_above_32 DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e421d1b5580791b0f7982dfb7",
                "question": [
                    "What is the average receiving moisture by location for commercial corn (material group 010) in harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  `scale_ticket_view`.`receiving_plant` AS plant_code,\n",
                            "  ROUND(AVG(`scale_ticket_view`.`moisture_percent`), 2) AS avg_receiving_moisture,\n",
                            "  COUNT(*) AS ticket_count,\n",
                            "  ROUND(MIN(`scale_ticket_view`.`moisture_percent`), 2) AS min_moisture,\n",
                            "  ROUND(MAX(`scale_ticket_view`.`moisture_percent`), 2) AS max_moisture\n",
                            "FROM\n",
                            "  `gso_prs_manufacturing_prod`.`bintelligence_app`.`scale_ticket_view`\n",
                            "WHERE\n",
                            "  `scale_ticket_view`.`moisture_percent` IS NOT NULL\n",
                            "  AND `scale_ticket_view`.`receiving_plant` IS NOT NULL\n",
                            "  AND `scale_ticket_view`.`harvest_year` = 2025\n",
                            "  AND `scale_ticket_view`.`material_group` = '010'\n",
                            "GROUP BY\n",
                            "  `scale_ticket_view`.`receiving_plant`\n",
                            "ORDER BY\n",
                            "  `scale_ticket_view`.`receiving_plant`"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e420810b3b810dcaeb3539aac",
                "question": [
                    "What is the total number of completed dryer bin fills by location for harvest year 2025?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  `hybrid_dex_current`.`plant_code`,\n",
                            "  CASE\n",
                            "    WHEN\n",
                            "      `hybrid_dex_current`.`plant_code` IN (\n",
                            "        'FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'SRO1'\n",
                            "      )\n",
                            "    THEN\n",
                            "      'Brazil'\n",
                            "    ELSE 'North America'\n",
                            "  END AS region,\n",
                            "  COUNT(DISTINCT `hybrid_dex_current`.`hybridex_key_pk`) AS total_completed_fills\n",
                            "FROM\n",
                            "  `gso_prs_manufacturing_prod`.`bintelligence_app`.`hybrid_dex_current`\n",
                            "WHERE\n",
                            "  `hybrid_dex_current`.`dex_status` = 'complete'\n",
                            "  AND `hybrid_dex_current`.`harvest_year` = 2025\n",
                            "GROUP BY\n",
                            "  `hybrid_dex_current`.`plant_code`\n",
                            "ORDER BY\n",
                            "  total_completed_fills DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f15e0e41f211b8a39b76cda0438002",
                "question": [
                    "What is the average drying rate by location for North America in harvest year 2025, and which locations are outside the ideal 3.5-4.5 range?"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  d.plant_code,\n",
                            "  COUNT(*) AS total_fills,\n",
                            "  ROUND(AVG(dr.drying_rate), 2) AS avg_drying_rate,\n",
                            "  CASE WHEN AVG(dr.drying_rate) BETWEEN 3.5 AND 4.5 THEN 'Conforming' ELSE 'Non-Conforming' END AS conformance_status\n",
                            "FROM gso_sandbox_dev.mike_larson_dev.drying_rate_table(p_harvest_year => 2025, p_trimester => 1, p_group_type => 'region', p_group_values => ARRAY('NA'), p_country_filter => NULL) dr\n",
                            "JOIN gso_prs_manufacturing_prod.bintelligence_app.hybrid_dex_current d\n",
                            "  ON dr.hybridex_key_pk = d.hybridex_key_pk\n",
                            "WHERE d.dex_status = 'complete'\n",
                            "GROUP BY d.plant_code\n",
                            "ORDER BY avg_drying_rate DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f11e3e7c431e7cb4b3f9bd6f23afd8",
                "question": [
                    "What was is the receiving volume for Brazil locations for harvest year 2025 trimester 2? "
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "SELECT\n",
                            "  `scale_ticket_view`.`receiving_plant`,\n",
                            "  SUM(`scale_ticket_view`.`ticket_units`) AS total_receiving_volume,\n",
                            "  COUNT(DISTINCT `scale_ticket_view`.`scale_ticket_id`) AS ticket_count,\n",
                            "  ROUND(AVG(`scale_ticket_view`.`ticket_units`), 2) AS avg_ticket_volume\n",
                            "FROM\n",
                            "  `gso_prs_manufacturing_prod`.`bintelligence_app`.`scale_ticket_view`\n",
                            "WHERE\n",
                            "  `scale_ticket_view`.`receiving_plant` IN (\n",
                            "    'FMA1', 'ITU1', 'CPP3', 'CRI1', 'ITU2', 'PMI1', 'PRC2', 'SHG1', 'PIL2', 'BSB1', 'SRO1'\n",
                            "  )\n",
                            "  AND `scale_ticket_view`.`harvest_year` = 2025\n",
                            "  AND `scale_ticket_view`.`material_group` = '010'\n",
                            "  AND `scale_ticket_view`.`harvest_trimester` = 2\n",
                            "  AND `scale_ticket_view`.`ticket_units` IS NOT NULL\n",
                            "GROUP BY\n",
                            "  `scale_ticket_view`.`receiving_plant`\n",
                            "ORDER BY\n",
                            "  total_receiving_volume DESC"
                        ]
                    }
                ]
            },
            {
                "id": "01f0f64e65601c10843e597386fef8bb",
                "question": [
                    "A location should optimize their shelling runs by shelling as much of the same material as possible as each time they change a material they have to do a change over. How often does a location change the material they are shelling before all the material has been shelled? If they change over a material only to change back to a previous material, this is inefficient"
                ],
                "answer": [
                    {
                        "format": "SQL",
                        "content": [
                            "WITH ordered_shells AS (\n",
                            "  SELECT\n",
                            "    gcr_plant AS plant_code,\n",
                            "    shelling_start_datetime,\n",
                            "    material_id,\n",
                            "    pioneer_lot_number,\n",
                            "    LAG(material_id) OVER (\n",
                            "        PARTITION BY gcr_plant\n",
                            "        ORDER BY shelling_start_datetime\n",
                            "      ) AS prev_material_id,\n",
                            "    LEAD(material_id) OVER (\n",
                            "        PARTITION BY gcr_plant\n",
                            "        ORDER BY shelling_start_datetime\n",
                            "      ) AS next_material_id\n",
                            "  FROM\n",
                            "    gso_rfd_manufacturing_prod.bintelligence.shellergrid\n",
                            "  WHERE\n",
                            "    shelling_start_datetime IS NOT NULL\n",
                            "    AND material_id IS NOT NULL\n",
                            "    AND gcr_plant IS NOT NULL\n",
                            "),\n",
                            "changeovers AS (\n",
                            "  SELECT\n",
                            "    plant_code,\n",
                            "    COUNT(*) AS total_shelling_runs,\n",
                            "    SUM(\n",
                            "      CASE\n",
                            "        WHEN material_id != prev_material_id THEN 1\n",
                            "        ELSE 0\n",
                            "      END\n",
                            "    ) AS material_changeovers,\n",
                            "    SUM(\n",
                            "      CASE\n",
                            "        WHEN material_id = prev_material_id THEN 0\n",
                            "        ELSE\n",
                            "          CASE\n",
                            "            WHEN material_id = next_material_id THEN 0\n",
                            "            ELSE 1\n",
                            "          END\n",
                            "      END\n",
                            "    ) AS inefficient_changebacks\n",
                            "  FROM\n",
                            "    ordered_shells\n",
                            "  GROUP BY\n",
                            "    plant_code\n",
                            ")\n",
                            "SELECT\n",
                            "  plant_code,\n",
                            "  total_shelling_runs,\n",
                            "  material_changeovers,\n",
                            "  inefficient_changebacks\n",
                            "FROM\n",
                            "  changeovers\n",
                            "ORDER BY\n",
                            "  plant_code;"
                        ]
                    }
                ]
            }
        ]
    }
}

# %%
import json

# Serialize the dict to a compact JSON string, then escape it for a SQL
# single-quoted string literal. Backslashes must be doubled first so JSON
# escapes like \"...\" survive SQL parsing, then single quotes are doubled.
serialized_space_json = json.dumps(serialized_space)
escaped_serialized_space = serialized_space_json.replace("\\", "\\\\").replace("'", "''")

insert_stmt = f"""INSERT INTO gso_rfd_lakehouse_config_dev.etl_configuration.genie_space_config_table (
    genie_space_id,
    genie_space_name,
    description,
    warehouse_id,
    serialized_space,
    parent_path,
    is_active
)
VALUES (
    '',
    'Bintelligence Genie',
    'This space provides detailed data and analytics for corn seed production, harvest, drying, and processing operations, enabling performance measurement and process optimization across plant locations.
    Ensure region, harvest year, and trimester are appropriately defined in prompts.
    Capabilities:
    Analyze dryer bin utilization, drying rates, and process efficiency by location, year, or region (North America vs. Brazil).
    Track receiving and drying moisture levels, truck loads, and material movement through each stage using unique identifiers.
    Monitor key seed production metrics: bin occupied duration, drying time, drying rate performance, shelling run optimization, and harvest schedule adherence.
    Filter data by completed/ongoing statuses, seasons, and valid fills for in-depth operational analysis.
    Support questions on network/plant-wide dryer turns, material flow, restart frequency, and more.
    Limitations:
    Cannot analyze non-corn crops or production processes outside the scope of the provided tables.
    Data is limited to seed corn handled in industrial dryer and receiving processes—does not include on-farm or small-batch operations.
    Some analyses may exclude records with incomplete or invalid status/fill information.
    Does not provide real-time data updates; reflects last refresh of source tables.',
    NULL,
    '{escaped_serialized_space}',
    '/Users/mehul.bhuva-1@corteva.com',
    true
);"""

print(insert_stmt)
# Out:
# INSERT INTO gso_rfd_lakehouse_config_dev.etl_configuration.genie_space_config_table (
#     genie_space_id,
#     genie_space_name,
#     description,
#     warehouse_id,
#     serialized_space,
#     parent_path,
#     is_active
# )
# VALUES (
#     '',
#     'Bintelligence Genie',
#     'This space provides detailed data and analytics for corn seed production, harvest, drying, and processing operations, enabling performance measurement and process optimization across plant locations.
#     Ensure region, harvest year, and trimester are appropriately defined in prompts.
#     Capabilities:
#     Analyze dryer bin utilization, drying rates, and process efficiency by location, year, or region (North America vs. Brazil).
#     Track receiving and drying moisture levels, truck loads, and material movement through each stage using unique identifiers.
# ...

# %%
import json

# 1) Serialize to compact JSON
serialized_space_json = json.dumps(serialized_space)

# 2) Escape for SQL single-quoted string: double backslashes, then double single quotes
escaped_serialized_space = serialized_space_json.replace("\\", "\\\\").replace("'", "''")

# 3) Build the full INSERT statement
insert_stmt = f"""INSERT INTO gso_rfd_lakehouse_config_dev.etl_configuration.genie_space_config_table (
    genie_space_id,
    genie_space_name,
    description,
    warehouse_id,
    serialized_space,
    parent_path,
    is_active
)
VALUES (
    '',
    'Bintelligence Genie',
    'This space provides detailed data and analytics for corn seed production, harvest, drying, and processing operations, enabling performance measurement and process optimization across plant locations.
    Ensure region, harvest year, and trimester are appropriately defined in prompts.
    Capabilities:
    Analyze dryer bin utilization, drying rates, and process efficiency by location, year, or region (North America vs. Brazil).
    Track receiving and drying moisture levels, truck loads, and material movement through each stage using unique identifiers.
    Monitor key seed production metrics: bin occupied duration, drying time, drying rate performance, shelling run optimization, and harvest schedule adherence.
    Filter data by completed/ongoing statuses, seasons, and valid fills for in-depth operational analysis.
    Support questions on network/plant-wide dryer turns, material flow, restart frequency, and more.
    Limitations:
    Cannot analyze non-corn crops or production processes outside the scope of the provided tables.
    Data is limited to seed corn handled in industrial dryer and receiving processes—does not include on-farm or small-batch operations.
    Some analyses may exclude records with incomplete or invalid status/fill information.
    Does not provide real-time data updates; reflects last refresh of source tables.',
    NULL,
    '{escaped_serialized_space}',
    '/Users/mehul.bhuva-1@corteva.com',
    true
);"""

# 4) Write to .sql file (avoids notebook output truncation)
sql_path = "/Workspace/Users/mehul.bhuva-1@vylor.com/BinTelligence_Genie_INSERT.sql"
with open(sql_path, "w", encoding="utf-8") as f:
    f.write(insert_stmt)

# 5) Also write the raw valid JSON for reference
json_path = "/Workspace/Users/mehul.bhuva-1@vylor.com/BinTelligence_Genie_serialized_space.json"
raw_json = json.dumps(serialized_space, indent=2)
with open(json_path, "w", encoding="utf-8") as f:
    f.write(raw_json)

# Verify the raw JSON round-trips
json.loads(raw_json)

print(f"INSERT statement written to: {sql_path}")
print(f"  Size: {len(insert_stmt):,} characters")
print(f"Raw JSON written to: {json_path}")
print(f"  Size: {len(raw_json):,} characters")
print("\nBoth files verified OK.")
# Out:
# INSERT statement written to: /Workspace/Users/mehul.bhuva-1@vylor.com/BinTelligence_Genie_INSERT.sql
#   Size: 147,055 characters
# Raw JSON written to: /Workspace/Users/mehul.bhuva-1@vylor.com/BinTelligence_Genie_serialized_space.json
#   Size: 203,824 characters
#
# Both files verified OK.
